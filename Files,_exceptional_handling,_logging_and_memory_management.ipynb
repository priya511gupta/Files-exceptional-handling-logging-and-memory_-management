# %% [markdown]
# **Files, exceptional handling,logging and memory management**

# %% [markdown]
# Question 1 -  What is the difference between interpreted and compiled languages?
#
# Answer - 1. Compiled Languages
#
# Process: The entire program’s source code is translated (compiled) into machine code before execution.
#
# Execution: The compiled machine code runs directly on the computer’s processor.
#
# Speed: Usually faster at runtime because translation is done in advance.
#
# Examples: C, C++, Rust, Go.
#
# Pros:
#
# High performance
#
# Better optimization by the compiler
#
# Cons:
#
# Need to recompile after code changes
#
# Compilation can take time for large projects
#
# 2. Interpreted Languages
#
# Process: The source code is read and executed line-by-line or instruction-by-instruction by an interpreter at runtime.
#
# Execution: The interpreter translates code to machine instructions on the fly.
#
# Speed: Usually slower at runtime because translation happens while running.
#
# Examples: Python, JavaScript, PHP.
#
# Pros:
#
# Easier to test and debug
#
# No separate compilation step
#
# Cons:
#
# Slower execution speed
#
# Interpreter must be present to run the code

# %% [markdown]
# Question 2 -  What is exception handling in Python?
#
# Answer - 1. What is an Exception?
#
# An exception is an event that interrupts the normal flow of a program when something goes wrong — for example:
#
# Dividing by zero → ZeroDivisionError
#
# Accessing an undefined variable → NameError
#
# Opening a non-existent file → FileNotFoundError
#
# 2. Why Exception Handling?
#
# Without exception handling, if an error occurs, Python will:
#
# Stop the program immediately
#
# Display an error message (traceback)
# With exception handling, you can:
#
# Catch the error
#
# Handle it gracefully (e.g., show a friendly message, retry the operation, log the error)

# %% [markdown]
# Question 3 -  What is the purpose of the finally block in exception handling?
#
# Answer - Purpose
#
# The finally block is mainly used for cleanup actions, such as:
#
# Closing files
#
# Releasing resources (like network or database connections)
#
# Resetting program states
#
# Logging completion of a process

# %% [markdown]
# Question 4 - What is logging in Python?
#
# Answer - Logging in Python is the process of recording messages about a program’s execution so you can track its behavior, debug issues, and monitor performance without interrupting the normal program flow.
#
# Instead of printing messages to the screen with print(), logging sends them to a log file or console with timestamps, severity levels, and more structured information.

# %% [markdown]
# Question 5 - What is the significance of the __del__ method in Python?
#
# Answer  -The __del__ method in Python is a destructor method — it’s called automatically just before an object is destroyed (garbage collected).
#
# Purpose
#
# To perform cleanup tasks before the object’s memory is released, such as:
#
# Closing files or network connections
#
# Releasing system resources
#
# Saving final state before deletion

# %% [markdown]
# Question 6 -  What is the difference between import and from ... import in Python?
#
# Answer - The main difference between import and from ... import in Python is how they bring code from a module into your program and how you access it afterward.
#
# 1. import
#
# Loads the entire module into your program.
#
# You must use the module name as a prefix to access its functions, classes, or variables.
#
# 2. from ... import
#
# Loads only the specified items from a module into your program’s current namespace.
#
# You can use them directly without the module prefix.

# %% [markdown]
# Question 7 -  How can you handle multiple exceptions in Python?
#
# Answer -
#
# 1)Purpose
#
# Programs may encounter different types of errors (exceptions) during runtime.
#
# Multiple exception handling allows us to catch and respond to each type appropriately.
#
# 2) Approaches
#
# a) Multiple except blocks
#
# Each exception type is caught in its own except clause.
#
# Useful when different exceptions require different corrective actions.
#
# b) Grouping exceptions in a tuple
#
# A single except clause can handle several exception types if they require the same response.
#
# Syntax: except (ErrorType1, ErrorType2):
#
# c) Generic Exception handling
#
# Using except Exception: catches any exception derived from Python’s base Exception class.
#
# Best used as a last resort to avoid missing unexpected errors.
#
# 3) Order of handling
#
# Python checks except clauses from top to bottom.
#
# More specific exceptions should come before more general ones, otherwise the specific ones may never be reached.
#
# 4) Best practices
#
# Handle only exceptions you expect and know how to deal with.
#
# Avoid using a broad except without logging or re-raising, as it may hide programming errors.
#
# Keep exception handling clear and readable for maintainability.

# %% [markdown]
# Question 8 -  What is the purpose of the with statement when handling files in Python?
#
# Answer - The with statement in Python is used to simplify resource management, especially when working with files, by automatically handling setup and cleanup tasks.
#
# Purpose
#
# Ensures that resources (like files, database connections, or network sockets) are properly released after use.
#
# Automatically calls the file object’s __enter__() method when the block starts and __exit__() method when the block ends.
#
# Eliminates the need to explicitly call file.close() — it’s done even if an exception occurs inside the block.

# %% [markdown]
# Question 9 -  What is the difference between multithreading and multiprocessing?
#
# Answer - 1. Multithreading
#
# Definition: Runs multiple threads (smaller units of a process) within the same process.
#
# Memory: All threads share the same memory space.
#
# Best for: I/O-bound tasks (e.g., file operations, network requests) where the program spends a lot of time waiting.
#
# Python Limitation: The Global Interpreter Lock (GIL) allows only one thread to execute Python bytecode at a time, so CPU-bound tasks don’t truly run in parallel.
#
# Example use cases:
#
# Downloading multiple files at once
#
# Reading from multiple network sockets
#
# Updating a GUI while processing data
#
# 2. Multiprocessing
#
# Definition: Runs multiple separate processes, each with its own Python interpreter and memory space.
#
# Memory: Each process has its own memory, so data must be passed between processes using pipes, queues, or shared memory.
#
# Best for: CPU-bound tasks (e.g., heavy calculations, data processing) that need true parallelism.
#
# Python Advantage: Not affected by the GIL — processes can use multiple CPU cores effectively.
#
# Example use cases:
#
# Image or video processing
#
# Large-scale numerical computations
#
# Machine learning model training

# %% [markdown]
# Question 10 -  What are the advantages of using logging in a program?
#
# Answer - Advantages of using logging in a program
#
# Logging is better than just using print() because it provides a structured, configurable, and reliable way to record what’s happening in your program.
#
# 1. Persistent records
#
# Logs can be saved to files, databases, or external systems.
#
# You can review them later to trace issues or analyze performance.
#
# 2. Debugging and troubleshooting
#
# Helps track errors, unexpected events, and program flow.
#
# Makes it easier to reproduce and fix bugs, especially in production environments.
#
# 3. Different log levels
#
# You can categorize messages as:
#
# DEBUG → Detailed info for developers
#
# INFO → General program progress
#
# WARNING → Something unusual but not fatal
#
# ERROR → Serious issue that needs fixing
#
# CRITICAL → Program may not be able to continue
#
# This helps filter messages based on importance.
#
# 4. Better control than print()
#
# You can easily turn logging on/off or change detail level without changing your code.
#
# Can log to multiple outputs at the same time (console, file, network).
#
# 5. Useful in production
#
# In live systems, printing to console might not be possible or useful.
#
# Logging keeps a history of what happened, even after the program ends.
#
# 6. Supports structured and formatted output
#
# Timestamps, severity levels, module names, and line numbers can be included automatically.
#
# Makes logs more informative and easier to analyze.

# %% [markdown]
# Question 11 -  What is memory management in Python?
#
# Answer - Memory management in Python refers to the process of allocating, tracking, and freeing memory that a Python program uses during execution. Python handles most of this automatically through its built-in memory manager and garbage collector.

# %% [markdown]
# Question 12 -  What are the basic steps involved in exception handling in Python?
#
# Answer - The basic steps involved in exception handling in Python follow a structured process to detect, catch, and handle errors without stopping the program abruptly.
#
# 1. Identify risky code
#
# Determine which part of your code might cause an exception (e.g., division, file access, type conversion).
#
# This code is placed inside a try block.
#
# 2. Attempt execution (try block)
#
# Python executes the code inside the try block.
#
# If no exception occurs → execution continues normally.
#
# If an exception occurs → Python jumps to the matching except block.
#
# 3. Catch the exception (except block)
#
# One or more except blocks specify which exceptions to handle.
#
# You can:
#
# Handle different exceptions separately.
#
# Handle multiple exceptions together using a tuple.
#
# Use a general except Exception as e to catch any exception.
#
# 4. Optional actions (else block)
#
# Runs only if no exception occurs.
#
# Useful for code that should only run when the try block succeeds.
#
# 5. Cleanup (finally block)
#
# Runs no matter what happens (exception or not).
#
# Commonly used for closing files, releasing resources, or cleanup operations.

# %% [markdown]
# Question 13 -  Why is memory management important in Python?
#
# Aswer - Memory management is important in Python because it directly affects a program’s performance, stability, and resource efficiency.
#
# Key Reasons
#
# Efficient use of resources
#
# Memory is limited; proper management ensures Python programs use only what they need and free unused memory quickly.
#
# Prevents memory leaks
#
# Without cleanup, unused objects could remain in memory, causing programs to slow down or crash.
#
# Improves performance
#
# Well-managed memory helps Python run faster by reducing unnecessary allocation and deallocation overhead.
#
# Supports long-running applications
#
# Web servers, data processing systems, and background services must manage memory carefully to avoid gradual slowdowns.
#
# Enables scalability
#
# Applications handling large datasets or many users rely on efficient memory usage to scale without exhausting resources.
#
# Automatic handling via garbage collection
#
# Python’s memory management (reference counting + garbage collector) automates cleanup, but developers still need to write code that doesn’t hold unnecessary references.

# %% [markdown]
# Question 14 - What is the role of try and except in exception handling?
#
# Answer - In Python’s exception handling, the try and except blocks work together to let your program detect and respond to errors instead of crashing.
#
# Role of try
#
# Marks the section of code that might raise an exception.
#
# Python executes this block line by line.
#
# If no error occurs → execution continues normally after the try block.
#
# If an error occurs → execution jumps immediately to the matching except block.
#
# Role of except
#
# Defines how to handle the error if one occurs in the try block.
#
# Runs only when the specified exception happens.
#
# Can:
#
# Catch specific errors (except ZeroDivisionError:)
#
# Catch multiple errors (except (ValueError, TypeError):)
#
# Catch all exceptions (except Exception as e:)

# %% [markdown]
# Question 15 -  How does Python's garbage collection system work?
#
# Answer - Python’s garbage collection system is responsible for automatically freeing memory used by objects that are no longer needed, so developers don’t have to manage memory manually.
#
# How it works
# 1. Reference Counting
#
# Python keeps track of how many references point to each object.
#
# Every object has a reference count (number of variables pointing to it).
#
# When the reference count drops to zero (no one is using it), Python immediately deallocates the object’s memory.
#
# 2. Garbage Collector for Circular References
#
# Sometimes objects reference each other, creating a circular reference:
#
# a = []
# b = []
# a.append(b)
# b.append(a)
#
#
# Even if there are no external references, their internal references keep the count above zero.
#
# Python’s garbage collector (gc module) detects and cleans up these cycles.

# %% [markdown]
# Question 16 - What is the purpose of the else block in exception handling?
#
# Answer - Purpose
#
# Separates error-handling code (except) from normal execution code.
#
# Makes programs more readable by clearly showing what should happen when everything goes right.
#
# Prevents mixing of main logic with error-handling logic.

# %% [markdown]
# Question 17 - What are the common logging levels in Python?
#
# Answer -
#
# Common Logging Levels
#
# (from lowest to highest severity):
#
# 1)DEBUG (Level 10)
#
# Detailed information, mostly useful for diagnosing problems during development.
#
# Example: variable values, function entry/exit messages.
#
# 2)INFO (Level 20)
#
# Confirms that things are working as expected.
#
# Example: “User logged in successfully.”
#
# 3)WARNING (Level 30)
#
# Indicates something unexpected happened or might cause a problem in the future, but the program is still running.
#
# Example: “Disk space running low.”
#
# 4)ERROR (Level 40)
#
# A serious problem occurred, preventing part of the program from functioning.
#
# Example: “Failed to open database connection.”
#
# 5)CRITICAL (Level 50)
#
# A very serious error that may prevent the program from continuing.
#
# Example: “Application crashed due to memory failure.”

# %% [markdown]
# Question 18 - What is the difference between os.fork() and multiprocessing in Python?
#
# Answer - 1. os.fork()
#
# Definition:
# A low-level system call that creates a new process by duplicating the current process.
#
# Platform support:
# ✅ Works only on Unix/Linux/macOS
# ❌ Not available on Windows.
#
# How it works:
# After calling fork(), two processes run simultaneously:
#
# Parent process → gets the child process ID as return value.
#
# Child process → gets 0 as return value.
#
# 2. multiprocessing Module
#
# Definition:
# A high-level Python module that provides an OS-independent API for creating and managing processes.
#
# Platform support:
# ✅ Works on Windows, Linux, macOS.
#
# How it works:
# Handles process creation internally using fork() (on Unix) or spawning new processes (on Windows).

# %% [markdown]
# Question 19 - What is the importance of closing a file in Python?
#
# Answer - Importance of Closing a File
#
# 1)Frees System Resources
#
# Every open file consumes memory and file descriptors (limited by the OS).
#
# Closing the file releases these resources.
#
# 2)Ensures Data is Written to Disk
#
# When writing to a file, Python often buffers data in memory for efficiency.
#
# Closing the file flushes this buffer, ensuring all data is saved to disk.
#
# 3)Prevents Data Corruption
#
# If a program ends without closing a file properly, the file may be left incomplete or corrupted.
#
# 4)Allows Other Programs to Access the File
#
# Some operating systems lock files while they are open.
#
# Closing releases the lock so other processes can read or write.
#
# 5)Good Programming Practice
#
# Closing files explicitly avoids unexpected behavior and improves code reliability.

# %% [markdown]
# Question 20 - What is the difference between file.read() and file.readline() in Python?
#
# Answer -1. file.read()
#
# Purpose: Reads the entire file content (or a specified number of characters/bytes) into a single string.
#
# When to use:
#
# When you need all data at once.
#
# Useful for small files.
#
# 2. file.readline()
#
# Purpose: Reads one line from the file at a time, including the newline character (\n) at the end.
#
# When to use:
#
# When you want to process a file line by line.
#
# Useful for large files to avoid loading everything into memory.

# %% [markdown]
# Question 21-  What is the logging module in Python used for?
#
# Answer - Main Purpose
#
# Keep track of events that happen while the program runs.
#
# Help debug issues by recording error messages and execution flow.
#
# Provide audit trails for security and compliance.
#
# Monitor application behavior in production.
#
# Why use logging instead of print()?
#
# More control over what is logged (levels like DEBUG, INFO, WARNING, ERROR, CRITICAL).
#
# Configurable output (console, file, network, etc.).
#
# Timestamps and context in log messages.
#
# Easier to disable or filter logs without changing the code logic.

# %% [markdown]
# Question 22 -  What is the os module in Python used for in file handling?
#
# Answer- The os module acts as Python’s bridge to the operating system, allowing you to manage files and directories beyond simple reading and writing.

# %% [markdown]
# Question 23 - What are the challenges associated with memory management in Python?
#
# Answer - The main challenges are reference cycles, memory leaks, retention of unused large objects, garbage collector overhead, fragmentation, and hidden memory usage. Efficient coding practices and profiling tools help mitigate these issues.

# %% [markdown]
# Question 24 - How do you raise an exception manually in Python?
#
# Answer - Use raise without arguments inside an except block to re-raise the current exception.
#
# You can raise built-in exceptions (ValueError, TypeError, RuntimeError, etc.) or custom-defined exceptions (by subclassing Exception).
#
# Raising exceptions helps enforce rules and handle unexpected conditions in code.

# %% [markdown]
# Question 25 - Why is it important to use multithreading in certain applications?
#
# Answer -Multithreading is important in certain applications because it allows multiple tasks to run concurrently within the same process, improving responsiveness and efficiency in specific scenarios.
#
# Key Reasons Why Multithreading is Important
# 1. Improved Responsiveness
#
# In GUI or interactive applications, multithreading ensures the interface remains responsive while background tasks (like file downloads or data processing) run.
#
# Example: A music player can play songs (thread 1) while downloading lyrics (thread 2).
#
# 2. Efficient I/O-bound Task Handling
#
# Multithreading is especially useful for I/O-bound tasks (network requests, file reading/writing, database queries) where the CPU often waits for external operations.
#
# Threads allow other tasks to proceed while waiting for I/O to complete.
#
# 3. Better Resource Utilization
#
# Even though Python’s Global Interpreter Lock (GIL) prevents true parallel execution of CPU-bound threads in CPython, threads still allow overlapping of waiting time with useful work.

# %%
#1  How can you open a file for writing in Python and write a string to it?

# Open file for writing and write a string
with open("example.txt", "w") as file:
    file.write("Hello, Python!")

# %%
#2 Write a Python program to read the contents of a file and print each line.

# Open the file in read mode
with open("example.txt", "r") as file:
    # Loop through each line and print it
    for line in file:
        print(line.strip())  # strip() removes extra newline characters
# Out:
# Hello, Python!

# %%
#3  How would you handle a case where the file doesn't exist while trying to open it for reading?

try:
    with open("example.txt", "r") as file:
        for line in file:
            print(line.strip())
except FileNotFoundError:
    print("Error: The file does not exist.")
# Out:
# Hello, Python!

# %%
#4 Write a Python script that reads from one file and writes its content to another file

# Read from one file and write to another
try:
    with open("source.txt", "r") as source_file:
        content = source_file.read()  # Read entire file

    with open("destination.txt", "w") as dest_file:
        dest_file.write(content)  # Write content to new file

    print("File copied successfully!")

except FileNotFoundError:
    print("Error: Source file does not exist.")
# Out:
# Error: Source file does not exist.

# %%
#5  How would you catch and handle division by zero error in Python?

try:
    num = 10
    denom = 0
    result = num / denom
    print("Result:", result)
except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
# Out:
# Error: Division by zero is not allowed.

# %%
#6 Write a Python program that logs an error message to a log file when a division by zero exception occurs.

import logging

# Configure logging to write to a file
logging.basicConfig(
    filename="error.log",           # Log file name
    level=logging.ERROR,            # Log only errors and above
    format="%(asctime)s - %(levelname)s - %(message)s"
)

try:
    num = 10
    denom = 0
    result = num / denom
    print("Result:", result)

except ZeroDivisionError as e:
    logging.error("Division by zero error occurred: %s", e)
    print("An error occurred. Check error.log for details.")
# Out:
# ERROR:root:Division by zero error occurred: division by zero
# An error occurred. Check error.log for details.

# %%
#7  How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?

import logging

# Configure logging
logging.basicConfig(
    filename="app.log",
    level=logging.DEBUG,  # Logs all levels from DEBUG and above
    format="%(asctime)s - %(levelname)s - %(message)s"
)

# Log messages at different levels
logging.debug("This is a DEBUG message (for detailed diagnostic information).")
logging.info("This is an INFO message (general information).")
logging.warning("This is a WARNING message (something unexpected, but program still works).")
logging.error("This is an ERROR message (something went wrong).")
logging.critical("This is a CRITICAL message (serious error, program may not continue).")
# Out:
# WARNING:root:This is a WARNING message (something unexpected, but program still works).
# ERROR:root:This is an ERROR message (something went wrong).
# CRITICAL:root:This is a CRITICAL message (serious error, program may not continue).

# %%
#8 Write a program to handle a file opening error using exception handling.

# Program to handle file opening error

try:
    with open("data.txt", "r") as file:
        content = file.read()
        print("File contents:")
        print(content)

except FileNotFoundError:
    print("Error: The file 'data.txt' was not found.")

except PermissionError:
    print("Error: You don't have permission to open this file.")

except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Error: The file 'data.txt' was not found.

# %%
#9  How can you read a file line by line and store its content in a list in Python?

# Read file line by line and store in a list
try:
    with open("sample.txt", "r") as file:
        lines = file.readlines()  # Returns a list where each element is a line

    # Remove trailing newline characters
    lines = [line.strip() for line in lines]

    print(lines)

except FileNotFoundError:
    print("Error: The file was not found.")
# Out:
# Error: The file was not found.

# %%
#10  How can you append data to an existing file in Python?

# Append data to an existing file
try:
    with open("example.txt", "a") as file:  # 'a' mode for appending
        file.write("\nThis is new data being appended.")

    print("Data appended successfully.")

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Data appended successfully.

# %%
#11  Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist.

# Program to handle missing dictionary key error

student = {
    "name": "Priya",
    "age": 22,
    "course": "Python Programming"
}

try:
    # Attempt to access a key that may not exist
    grade = student["grade"]
    print("Grade:", grade)

except KeyError:
    print("Error: The key 'grade' does not exist in the dictionary.")
# Out:
# Error: The key 'grade' does not exist in the dictionary.

# %%
#12 Write a program that demonstrates using multiple except blocks to handle different types of exceptions.

# Program to demonstrate multiple except blocks

try:
    # Example operations that can raise different errors
    num1 = int(input("Enter a number: "))
    num2 = int(input("Enter another number: "))
    result = num1 / num2  # Can cause ZeroDivisionError

    print("Result:", result)

    # Accessing a non-existent dictionary key
    my_dict = {"name": "Priya"}
    print("Age:", my_dict["age"])  # Can cause KeyError

except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")

except ValueError:
    print("Error: Invalid input. Please enter a valid number.")

except KeyError:
    print("Error: The requested key does not exist in the dictionary.")

except Exception as e:
    print(f"An unexpected error occurred: {e}")

# %%
#13 How would you check if a file exists before attempting to read it in Python?

import os

filename = "sample.txt"

if os.path.exists(filename):
    with open(filename, "r") as file:
        content = file.read()
        print(content)
else:
    print(f"Error: The file '{filename}' does not exist.")
# Out:
# Error: The file 'sample.txt' does not exist.

# %%
#14  Write a program that uses the logging module to log both informational and error messages.

import logging

# Configure logging settings
logging.basicConfig(
    filename="app.log",       # Log file name
    level=logging.DEBUG,      # Capture all levels of logs
    format="%(asctime)s - %(levelname)s - %(message)s"
)

# Log an informational message
logging.info("Application started successfully.")

try:
    num1 = 10
    num2 = 0
    result = num1 / num2  # This will cause ZeroDivisionError
    logging.info(f"Result: {result}")

except ZeroDivisionError:
    logging.error("Attempted to divide by zero.")

# Another informational message
logging.info("Application finished running.")
# Out:
# ERROR:root:Attempted to divide by zero.

# %%
#15  Write a Python program that prints the content of a file and handles the case when the file is empty.

# Program to read a file and handle empty file case

filename = "sample.txt"

try:
    with open(filename, "r") as file:
        content = file.read()

        if content.strip() == "":  # Remove spaces/newlines before checking
            print("The file is empty.")
        else:
            print("File content:\n")
            print(content)

except FileNotFoundError:
    print(f"Error: The file '{filename}' does not exist.")
# Out:
# Error: The file 'sample.txt' does not exist.

# %%
#16  Demonstrate how to use memory profiling to check the memory usage of a small program.

from memory_profiler import profile

@profile
def create_lists():
    # Small list
    small_list = [i for i in range(1000)]

    # Larger list
    large_list = [i * 2 for i in range(100000)]

    # Delete large list to free memory
    del large_list

    return small_list

if __name__ == "__main__":
    create_lists()

# %%
#17  Write a Python program to create and write a list of numbers to a file, one number per line.

# Program to write numbers to a file, one per line

numbers = [10, 20, 30, 40, 50]
filename = "numbers.txt"

try:
    with open(filename, "w") as file:
        for num in numbers:
            file.write(str(num) + "\n")  # Convert number to string before writing
    print(f"Numbers written to {filename} successfully.")

except IOError as e:
    print(f"An error occurred while writing to the file: {e}")
# Out:
# Numbers written to numbers.txt successfully.

# %%
#18 How would you implement a basic logging setup that logs to a file with rotation after 1MB?

import logging
from logging.handlers import RotatingFileHandler

# Create a logger
logger = logging.getLogger("MyLogger")
logger.setLevel(logging.DEBUG)  # Log all levels

# Create a rotating file handler
handler = RotatingFileHandler(
    "app.log",       # Log file name
    maxBytes=1_000_000,  # Rotate after 1MB
    backupCount=3        # Keep last 3 backups
)

# Create a log format
formatter = logging.Formatter("%(asctime)s - %(levelname)s - %(message)s")
handler.setFormatter(formatter)

# Add handler to logger
logger.addHandler(handler)

# Example logs
for i in range(5000):
    logger.info(f"Logging message {i}")
# Out:
# INFO:MyLogger:Logging message 0
# INFO:MyLogger:Logging message 1
# INFO:MyLogger:Logging message 2
# INFO:MyLogger:Logging message 3
# INFO:MyLogger:Logging message 4
# INFO:MyLogger:Logging message 5
# INFO:MyLogger:Logging message 6
# INFO:MyLogger:Logging message 7
# INFO:MyLogger:Logging message 8
# INFO:MyLogger:Logging message 9
# INFO:MyLogger:Logging message 10
# INFO:MyLogger:Logging message 11
# INFO:MyLogger:Logging message 12
# INFO:MyLogger:Logging message 13
# INFO:MyLogger:Logging message 14
# INFO:MyLogger:Logging message 15
# INFO:MyLogger:Logging message 16
# INFO:MyLogger:Logging message 17
# INFO:MyLogger:Logging message 18
# INFO:MyLogger:Logging message 19
# INFO:MyLogger:Logging message 20
# INFO:MyLogger:Logging message 21
# INFO:MyLogger:Logging message 22
# INFO:MyLogger:Logging message 23
# INFO:MyLogger:Logging message 24
# INFO:MyLogger:Logging message 25
# INFO:MyLogger:Logging message 26
# INFO:MyLogger:Logging message 27
# INFO:MyLogger:Logging message 28
# INFO:MyLogger:Logging message 29
# INFO:MyLogger:Logging message 30
# INFO:MyLogger:Logging message 31
# INFO:MyLogger:Logging message 32
# INFO:MyLogger:Logging message 33
# INFO:MyLogger:Logging message 34
# INFO:MyLogger:Logging message 35
# INFO:MyLogger:Logging message 36
# INFO:MyLogger:Logging message 37
# INFO:MyLogger:Logging message 38
# INFO:MyLogger:Logging message 39
# INFO:MyLogger:Logging message 40
# INFO:MyLogger:Logging message 41
# INFO:MyLogger:Logging message 42
# INFO:MyLogger:Logging message 43
# INFO:MyLogger:Logging message 44
# INFO:MyLogger:Logging message 45
# INFO:MyLogger:Logging message 46
# INFO:MyLogger:Logging message 47
# INFO:MyLogger:Logging message 48
# INFO:MyLogger:Logging message 49
# INFO:MyLogger:Logging message 50
# INFO:MyLogger:Logging message 51
# INFO:MyLogger:Logging message 52
# INFO:MyLogger:Logging message 53
# INFO:MyLogger:Logging message 54
# INFO:MyLogger:Logging message 55
# INFO:MyLogger:Logging message 56
# INFO:MyLogger:Logging message 57
# INFO:MyLogger:Logging message 58
# INFO:MyLogger:Logging message 59
# INFO:MyLogger:Logging message 60
# INFO:MyLogger:Logging message 61
# INFO:MyLogger:Logging message 62
# INFO:MyLogger:Logging message 63
# INFO:MyLogger:Logging message 64
# INFO:MyLogger:Logging message 65
# INFO:MyLogger:Logging message 66
# INFO:MyLogger:Logging message 67
# INFO:MyLogger:Logging message 68
# INFO:MyLogger:Logging message 69
# INFO:MyLogger:Logging message 70
# INFO:MyLogger:Logging message 71
# INFO:MyLogger:Logging message 72
# INFO:MyLogger:Logging message 73
# INFO:MyLogger:Logging message 74
# INFO:MyLogger:Logging message 75
# INFO:MyLogger:Logging message 76
# INFO:MyLogger:Logging message 77
# INFO:MyLogger:Logging message 78
# INFO:MyLogger:Logging message 79
# INFO:MyLogger:Logging message 80
# INFO:MyLogger:Logging message 81
# INFO:MyLogger:Logging message 82
# INFO:MyLogger:Logging message 83
# INFO:MyLogger:Logging message 84
# INFO:MyLogger:Logging message 85
# INFO:MyLogger:Logging message 86
# INFO:MyLogger:Logging message 87
# INFO:MyLogger:Logging message 88
# INFO:MyLogger:Logging message 89
# INFO:MyLogger:Logging message 90
# INFO:MyLogger:Logging message 91
# INFO:MyLogger:Logging message 92
# INFO:MyLogger:Logging message 93
# INFO:MyLogger:Logging message 94
# INFO:MyLogger:Logging message 95
# INFO:MyLogger:Logging message 96
# INFO:MyLogger:Logging message 97
# INFO:MyLogger:Logging message 98
# INFO:MyLogger:Logging message 99
# INFO:MyLogger:Logging message 100
# INFO:MyLogger:Logging message 101
# INFO:MyLogger:Logging message 102
# INFO:MyLogger:Logging message 103
# INFO:MyLogger:Logging message 104
# INFO:MyLogger:Logging message 105
# INFO:MyLogger:Logging message 106
# INFO:MyLogger:Logging message 107
# INFO:MyLogger:Logging message 108
# INFO:MyLogger:Logging message 109
# INFO:MyLogger:Logging message 110
# INFO:MyLogger:Logging message 111
# INFO:MyLogger:Logging message 112
# INFO:MyLogger:Logging message 113
# INFO:MyLogger:Logging message 114
# INFO:MyLogger:Logging message 115
# INFO:MyLogger:Logging message 116
# INFO:MyLogger:Logging message 117
# INFO:MyLogger:Logging message 118
# INFO:MyLogger:Logging message 119
# INFO:MyLogger:Logging message 120
# INFO:MyLogger:Logging message 121
# INFO:MyLogger:Logging message 122
# INFO:MyLogger:Logging message 123
# INFO:MyLogger:Logging message 124
# INFO:MyLogger:Logging message 125
# INFO:MyLogger:Logging message 126
# INFO:MyLogger:Logging message 127
# INFO:MyLogger:Logging message 128
# INFO:MyLogger:Logging message 129
# INFO:MyLogger:Logging message 130
# INFO:MyLogger:Logging message 131
# INFO:MyLogger:Logging message 132
# INFO:MyLogger:Logging message 133
# INFO:MyLogger:Logging message 134
# INFO:MyLogger:Logging message 135
# INFO:MyLogger:Logging message 136
# INFO:MyLogger:Logging message 137
# INFO:MyLogger:Logging message 138
# INFO:MyLogger:Logging message 139
# INFO:MyLogger:Logging message 140
# INFO:MyLogger:Logging message 141
# INFO:MyLogger:Logging message 142
# INFO:MyLogger:Logging message 143
# INFO:MyLogger:Logging message 144
# INFO:MyLogger:Logging message 145
# INFO:MyLogger:Logging message 146
# INFO:MyLogger:Logging message 147
# INFO:MyLogger:Logging message 148
# INFO:MyLogger:Logging message 149
# INFO:MyLogger:Logging message 150
# INFO:MyLogger:Logging message 151
# INFO:MyLogger:Logging message 152
# INFO:MyLogger:Logging message 153
# INFO:MyLogger:Logging message 154
# INFO:MyLogger:Logging message 155
# INFO:MyLogger:Logging message 156
# INFO:MyLogger:Logging message 157
# INFO:MyLogger:Logging message 158
# INFO:MyLogger:Logging message 159
# INFO:MyLogger:Logging message 160
# INFO:MyLogger:Logging message 161
# INFO:MyLogger:Logging message 162
# INFO:MyLogger:Logging message 163
# INFO:MyLogger:Logging message 164
# INFO:MyLogger:Logging message 165
# INFO:MyLogger:Logging message 166
# INFO:MyLogger:Logging message 167
# INFO:MyLogger:Logging message 168
# INFO:MyLogger:Logging message 169
# INFO:MyLogger:Logging message 170
# INFO:MyLogger:Logging message 171
# INFO:MyLogger:Logging message 172
# INFO:MyLogger:Logging message 173
# INFO:MyLogger:Logging message 174
# INFO:MyLogger:Logging message 175
# INFO:MyLogger:Logging message 176
# INFO:MyLogger:Logging message 177
# INFO:MyLogger:Logging message 178
# INFO:MyLogger:Logging message 179
# INFO:MyLogger:Logging message 180
# INFO:MyLogger:Logging message 181
# INFO:MyLogger:Logging message 182
# INFO:MyLogger:Logging message 183
# INFO:MyLogger:Logging message 184
# INFO:MyLogger:Logging message 185
# INFO:MyLogger:Logging message 186
# INFO:MyLogger:Logging message 187
# INFO:MyLogger:Logging message 188
# INFO:MyLogger:Logging message 189
# INFO:MyLogger:Logging message 190
# INFO:MyLogger:Logging message 191
# INFO:MyLogger:Logging message 192
# INFO:MyLogger:Logging message 193
# INFO:MyLogger:Logging message 194
# INFO:MyLogger:Logging message 195
# INFO:MyLogger:Logging message 196
# INFO:MyLogger:Logging message 197
# INFO:MyLogger:Logging message 198
# INFO:MyLogger:Logging message 199
# INFO:MyLogger:Logging message 200
# INFO:MyLogger:Logging message 201
# INFO:MyLogger:Logging message 202
# INFO:MyLogger:Logging message 203
# INFO:MyLogger:Logging message 204
# INFO:MyLogger:Logging message 205
# INFO:MyLogger:Logging message 206
# INFO:MyLogger:Logging message 207
# INFO:MyLogger:Logging message 208
# INFO:MyLogger:Logging message 209
# INFO:MyLogger:Logging message 210
# INFO:MyLogger:Logging message 211
# INFO:MyLogger:Logging message 212
# INFO:MyLogger:Logging message 213
# INFO:MyLogger:Logging message 214
# INFO:MyLogger:Logging message 215
# INFO:MyLogger:Logging message 216
# INFO:MyLogger:Logging message 217
# INFO:MyLogger:Logging message 218
# INFO:MyLogger:Logging message 219
# INFO:MyLogger:Logging message 220
# INFO:MyLogger:Logging message 221
# INFO:MyLogger:Logging message 222
# INFO:MyLogger:Logging message 223
# INFO:MyLogger:Logging message 224
# INFO:MyLogger:Logging message 225
# INFO:MyLogger:Logging message 226
# INFO:MyLogger:Logging message 227
# INFO:MyLogger:Logging message 228
# INFO:MyLogger:Logging message 229
# INFO:MyLogger:Logging message 230
# INFO:MyLogger:Logging message 231
# INFO:MyLogger:Logging message 232
# INFO:MyLogger:Logging message 233
# INFO:MyLogger:Logging message 234
# INFO:MyLogger:Logging message 235
# INFO:MyLogger:Logging message 236
# INFO:MyLogger:Logging message 237
# INFO:MyLogger:Logging message 238
# INFO:MyLogger:Logging message 239
# INFO:MyLogger:Logging message 240
# INFO:MyLogger:Logging message 241
# INFO:MyLogger:Logging message 242
# INFO:MyLogger:Logging message 243
# INFO:MyLogger:Logging message 244
# INFO:MyLogger:Logging message 245
# INFO:MyLogger:Logging message 246
# INFO:MyLogger:Logging message 247
# INFO:MyLogger:Logging message 248
# INFO:MyLogger:Logging message 249
# INFO:MyLogger:Logging message 250
# INFO:MyLogger:Logging message 251
# INFO:MyLogger:Logging message 252
# INFO:MyLogger:Logging message 253
# INFO:MyLogger:Logging message 254
# INFO:MyLogger:Logging message 255
# INFO:MyLogger:Logging message 256
# INFO:MyLogger:Logging message 257
# INFO:MyLogger:Logging message 258
# INFO:MyLogger:Logging message 259
# INFO:MyLogger:Logging message 260
# INFO:MyLogger:Logging message 261
# INFO:MyLogger:Logging message 262
# INFO:MyLogger:Logging message 263
# INFO:MyLogger:Logging message 264
# INFO:MyLogger:Logging message 265
# INFO:MyLogger:Logging message 266
# INFO:MyLogger:Logging message 267
# INFO:MyLogger:Logging message 268
# INFO:MyLogger:Logging message 269
# INFO:MyLogger:Logging message 270
# INFO:MyLogger:Logging message 271
# INFO:MyLogger:Logging message 272
# INFO:MyLogger:Logging message 273
# INFO:MyLogger:Logging message 274
# INFO:MyLogger:Logging message 275
# INFO:MyLogger:Logging message 276
# INFO:MyLogger:Logging message 277
# INFO:MyLogger:Logging message 278
# INFO:MyLogger:Logging message 279
# INFO:MyLogger:Logging message 280
# INFO:MyLogger:Logging message 281
# INFO:MyLogger:Logging message 282
# INFO:MyLogger:Logging message 283
# INFO:MyLogger:Logging message 284
# INFO:MyLogger:Logging message 285
# INFO:MyLogger:Logging message 286
# INFO:MyLogger:Logging message 287
# INFO:MyLogger:Logging message 288
# INFO:MyLogger:Logging message 289
# INFO:MyLogger:Logging message 290
# INFO:MyLogger:Logging message 291
# INFO:MyLogger:Logging message 292
# INFO:MyLogger:Logging message 293
# INFO:MyLogger:Logging message 294
# INFO:MyLogger:Logging message 295
# INFO:MyLogger:Logging message 296
# INFO:MyLogger:Logging message 297
# INFO:MyLogger:Logging message 298
# INFO:MyLogger:Logging message 299
# INFO:MyLogger:Logging message 300
# INFO:MyLogger:Logging message 301
# INFO:MyLogger:Logging message 302
# INFO:MyLogger:Logging message 303
# INFO:MyLogger:Logging message 304
# INFO:MyLogger:Logging message 305
# INFO:MyLogger:Logging message 306
# INFO:MyLogger:Logging message 307
# INFO:MyLogger:Logging message 308
# INFO:MyLogger:Logging message 309
# INFO:MyLogger:Logging message 310
# INFO:MyLogger:Logging message 311
# INFO:MyLogger:Logging message 312
# INFO:MyLogger:Logging message 313
# INFO:MyLogger:Logging message 314
# INFO:MyLogger:Logging message 315
# INFO:MyLogger:Logging message 316
# INFO:MyLogger:Logging message 317
# INFO:MyLogger:Logging message 318
# INFO:MyLogger:Logging message 319
# INFO:MyLogger:Logging message 320
# INFO:MyLogger:Logging message 321
# INFO:MyLogger:Logging message 322
# INFO:MyLogger:Logging message 323
# INFO:MyLogger:Logging message 324
# INFO:MyLogger:Logging message 325
# INFO:MyLogger:Logging message 326
# INFO:MyLogger:Logging message 327
# INFO:MyLogger:Logging message 328
# INFO:MyLogger:Logging message 329
# INFO:MyLogger:Logging message 330
# INFO:MyLogger:Logging message 331
# INFO:MyLogger:Logging message 332
# INFO:MyLogger:Logging message 333
# INFO:MyLogger:Logging message 334
# INFO:MyLogger:Logging message 335
# INFO:MyLogger:Logging message 336
# INFO:MyLogger:Logging message 337
# INFO:MyLogger:Logging message 338
# INFO:MyLogger:Logging message 339
# INFO:MyLogger:Logging message 340
# INFO:MyLogger:Logging message 341
# INFO:MyLogger:Logging message 342
# INFO:MyLogger:Logging message 343
# INFO:MyLogger:Logging message 344
# INFO:MyLogger:Logging message 345
# INFO:MyLogger:Logging message 346
# INFO:MyLogger:Logging message 347
# INFO:MyLogger:Logging message 348
# INFO:MyLogger:Logging message 349
# INFO:MyLogger:Logging message 350
# INFO:MyLogger:Logging message 351
# INFO:MyLogger:Logging message 352
# INFO:MyLogger:Logging message 353
# INFO:MyLogger:Logging message 354
# INFO:MyLogger:Logging message 355
# INFO:MyLogger:Logging message 356
# INFO:MyLogger:Logging message 357
# INFO:MyLogger:Logging message 358
# INFO:MyLogger:Logging message 359
# INFO:MyLogger:Logging message 360
# INFO:MyLogger:Logging message 361
# INFO:MyLogger:Logging message 362
# INFO:MyLogger:Logging message 363
# INFO:MyLogger:Logging message 364
# INFO:MyLogger:Logging message 365
# INFO:MyLogger:Logging message 366
# INFO:MyLogger:Logging message 367
# INFO:MyLogger:Logging message 368
# INFO:MyLogger:Logging message 369
# INFO:MyLogger:Logging message 370
# INFO:MyLogger:Logging message 371
# INFO:MyLogger:Logging message 372
# INFO:MyLogger:Logging message 373
# INFO:MyLogger:Logging message 374
# INFO:MyLogger:Logging message 375
# INFO:MyLogger:Logging message 376
# INFO:MyLogger:Logging message 377
# INFO:MyLogger:Logging message 378
# INFO:MyLogger:Logging message 379
# INFO:MyLogger:Logging message 380
# INFO:MyLogger:Logging message 381
# INFO:MyLogger:Logging message 382
# INFO:MyLogger:Logging message 383
# INFO:MyLogger:Logging message 384
# INFO:MyLogger:Logging message 385
# INFO:MyLogger:Logging message 386
# INFO:MyLogger:Logging message 387
# INFO:MyLogger:Logging message 388
# INFO:MyLogger:Logging message 389
# INFO:MyLogger:Logging message 390
# INFO:MyLogger:Logging message 391
# INFO:MyLogger:Logging message 392
# INFO:MyLogger:Logging message 393
# INFO:MyLogger:Logging message 394
# INFO:MyLogger:Logging message 395
# INFO:MyLogger:Logging message 396
# INFO:MyLogger:Logging message 397
# INFO:MyLogger:Logging message 398
# INFO:MyLogger:Logging message 399
# INFO:MyLogger:Logging message 400
# INFO:MyLogger:Logging message 401
# INFO:MyLogger:Logging message 402
# INFO:MyLogger:Logging message 403
# INFO:MyLogger:Logging message 404
# INFO:MyLogger:Logging message 405
# INFO:MyLogger:Logging message 406
# INFO:MyLogger:Logging message 407
# INFO:MyLogger:Logging message 408
# INFO:MyLogger:Logging message 409
# INFO:MyLogger:Logging message 410
# INFO:MyLogger:Logging message 411
# INFO:MyLogger:Logging message 412
# INFO:MyLogger:Logging message 413
# INFO:MyLogger:Logging message 414
# INFO:MyLogger:Logging message 415
# INFO:MyLogger:Logging message 416
# INFO:MyLogger:Logging message 417
# INFO:MyLogger:Logging message 418
# INFO:MyLogger:Logging message 419
# INFO:MyLogger:Logging message 420
# INFO:MyLogger:Logging message 421
# INFO:MyLogger:Logging message 422
# INFO:MyLogger:Logging message 423
# INFO:MyLogger:Logging message 424
# INFO:MyLogger:Logging message 425
# INFO:MyLogger:Logging message 426
# INFO:MyLogger:Logging message 427
# INFO:MyLogger:Logging message 428
# INFO:MyLogger:Logging message 429
# INFO:MyLogger:Logging message 430
# INFO:MyLogger:Logging message 431
# INFO:MyLogger:Logging message 432
# INFO:MyLogger:Logging message 433
# INFO:MyLogger:Logging message 434
# INFO:MyLogger:Logging message 435
# INFO:MyLogger:Logging message 436
# INFO:MyLogger:Logging message 437
# INFO:MyLogger:Logging message 438
# INFO:MyLogger:Logging message 439
# INFO:MyLogger:Logging message 440
# INFO:MyLogger:Logging message 441
# INFO:MyLogger:Logging message 442
# INFO:MyLogger:Logging message 443
# INFO:MyLogger:Logging message 444
# INFO:MyLogger:Logging message 445
# INFO:MyLogger:Logging message 446
# INFO:MyLogger:Logging message 447
# INFO:MyLogger:Logging message 448
# INFO:MyLogger:Logging message 449
# INFO:MyLogger:Logging message 450
# INFO:MyLogger:Logging message 451
# INFO:MyLogger:Logging message 452
# INFO:MyLogger:Logging message 453
# INFO:MyLogger:Logging message 454
# INFO:MyLogger:Logging message 455
# INFO:MyLogger:Logging message 456
# INFO:MyLogger:Logging message 457
# INFO:MyLogger:Logging message 458
# INFO:MyLogger:Logging message 459
# INFO:MyLogger:Logging message 460
# INFO:MyLogger:Logging message 461
# INFO:MyLogger:Logging message 462
# INFO:MyLogger:Logging message 463
# INFO:MyLogger:Logging message 464
# INFO:MyLogger:Logging message 465
# INFO:MyLogger:Logging message 466
# INFO:MyLogger:Logging message 467
# INFO:MyLogger:Logging message 468
# INFO:MyLogger:Logging message 469
# INFO:MyLogger:Logging message 470
# INFO:MyLogger:Logging message 471
# INFO:MyLogger:Logging message 472
# INFO:MyLogger:Logging message 473
# INFO:MyLogger:Logging message 474
# INFO:MyLogger:Logging message 475
# INFO:MyLogger:Logging message 476
# INFO:MyLogger:Logging message 477
# INFO:MyLogger:Logging message 478
# INFO:MyLogger:Logging message 479
# INFO:MyLogger:Logging message 480
# INFO:MyLogger:Logging message 481
# INFO:MyLogger:Logging message 482
# INFO:MyLogger:Logging message 483
# INFO:MyLogger:Logging message 484
# INFO:MyLogger:Logging message 485
# INFO:MyLogger:Logging message 486
# INFO:MyLogger:Logging message 487
# INFO:MyLogger:Logging message 488
# INFO:MyLogger:Logging message 489
# INFO:MyLogger:Logging message 490
# INFO:MyLogger:Logging message 491
# INFO:MyLogger:Logging message 492
# INFO:MyLogger:Logging message 493
# INFO:MyLogger:Logging message 494
# INFO:MyLogger:Logging message 495
# INFO:MyLogger:Logging message 496
# INFO:MyLogger:Logging message 497
# INFO:MyLogger:Logging message 498
# INFO:MyLogger:Logging message 499
# INFO:MyLogger:Logging message 500
# INFO:MyLogger:Logging message 501
# INFO:MyLogger:Logging message 502
# INFO:MyLogger:Logging message 503
# INFO:MyLogger:Logging message 504
# INFO:MyLogger:Logging message 505
# INFO:MyLogger:Logging message 506
# INFO:MyLogger:Logging message 507
# INFO:MyLogger:Logging message 508
# INFO:MyLogger:Logging message 509
# INFO:MyLogger:Logging message 510
# INFO:MyLogger:Logging message 511
# INFO:MyLogger:Logging message 512
# INFO:MyLogger:Logging message 513
# INFO:MyLogger:Logging message 514
# INFO:MyLogger:Logging message 515
# INFO:MyLogger:Logging message 516
# INFO:MyLogger:Logging message 517
# INFO:MyLogger:Logging message 518
# INFO:MyLogger:Logging message 519
# INFO:MyLogger:Logging message 520
# INFO:MyLogger:Logging message 521
# INFO:MyLogger:Logging message 522
# INFO:MyLogger:Logging message 523
# INFO:MyLogger:Logging message 524
# INFO:MyLogger:Logging message 525
# INFO:MyLogger:Logging message 526
# INFO:MyLogger:Logging message 527
# INFO:MyLogger:Logging message 528
# INFO:MyLogger:Logging message 529
# INFO:MyLogger:Logging message 530
# INFO:MyLogger:Logging message 531
# INFO:MyLogger:Logging message 532
# INFO:MyLogger:Logging message 533
# INFO:MyLogger:Logging message 534
# INFO:MyLogger:Logging message 535
# INFO:MyLogger:Logging message 536
# INFO:MyLogger:Logging message 537
# INFO:MyLogger:Logging message 538
# INFO:MyLogger:Logging message 539
# INFO:MyLogger:Logging message 540
# INFO:MyLogger:Logging message 541
# INFO:MyLogger:Logging message 542
# INFO:MyLogger:Logging message 543
# INFO:MyLogger:Logging message 544
# INFO:MyLogger:Logging message 545
# INFO:MyLogger:Logging message 546
# INFO:MyLogger:Logging message 547
# INFO:MyLogger:Logging message 548
# INFO:MyLogger:Logging message 549
# INFO:MyLogger:Logging message 550
# INFO:MyLogger:Logging message 551
# INFO:MyLogger:Logging message 552
# INFO:MyLogger:Logging message 553
# INFO:MyLogger:Logging message 554
# INFO:MyLogger:Logging message 555
# INFO:MyLogger:Logging message 556
# INFO:MyLogger:Logging message 557
# INFO:MyLogger:Logging message 558
# INFO:MyLogger:Logging message 559
# INFO:MyLogger:Logging message 560
# INFO:MyLogger:Logging message 561
# INFO:MyLogger:Logging message 562
# INFO:MyLogger:Logging message 563
# INFO:MyLogger:Logging message 564
# INFO:MyLogger:Logging message 565
# INFO:MyLogger:Logging message 566
# INFO:MyLogger:Logging message 567
# INFO:MyLogger:Logging message 568
# INFO:MyLogger:Logging message 569
# INFO:MyLogger:Logging message 570
# INFO:MyLogger:Logging message 571
# INFO:MyLogger:Logging message 572
# INFO:MyLogger:Logging message 573
# INFO:MyLogger:Logging message 574
# INFO:MyLogger:Logging message 575
# INFO:MyLogger:Logging message 576
# INFO:MyLogger:Logging message 577
# INFO:MyLogger:Logging message 578
# INFO:MyLogger:Logging message 579
# INFO:MyLogger:Logging message 580
# INFO:MyLogger:Logging message 581
# INFO:MyLogger:Logging message 582
# INFO:MyLogger:Logging message 583
# INFO:MyLogger:Logging message 584
# INFO:MyLogger:Logging message 585
# INFO:MyLogger:Logging message 586
# INFO:MyLogger:Logging message 587
# INFO:MyLogger:Logging message 588
# INFO:MyLogger:Logging message 589
# INFO:MyLogger:Logging message 590
# INFO:MyLogger:Logging message 591
# INFO:MyLogger:Logging message 592
# INFO:MyLogger:Logging message 593
# INFO:MyLogger:Logging message 594
# INFO:MyLogger:Logging message 595
# INFO:MyLogger:Logging message 596
# INFO:MyLogger:Logging message 597
# INFO:MyLogger:Logging message 598
# INFO:MyLogger:Logging message 599
# INFO:MyLogger:Logging message 600
# INFO:MyLogger:Logging message 601
# INFO:MyLogger:Logging message 602
# INFO:MyLogger:Logging message 603
# INFO:MyLogger:Logging message 604
# INFO:MyLogger:Logging message 605
# INFO:MyLogger:Logging message 606
# INFO:MyLogger:Logging message 607
# INFO:MyLogger:Logging message 608
# INFO:MyLogger:Logging message 609
# INFO:MyLogger:Logging message 610
# INFO:MyLogger:Logging message 611
# INFO:MyLogger:Logging message 612
# INFO:MyLogger:Logging message 613
# INFO:MyLogger:Logging message 614
# INFO:MyLogger:Logging message 615
# INFO:MyLogger:Logging message 616
# INFO:MyLogger:Logging message 617
# INFO:MyLogger:Logging message 618
# INFO:MyLogger:Logging message 619
# INFO:MyLogger:Logging message 620
# INFO:MyLogger:Logging message 621
# INFO:MyLogger:Logging message 622
# INFO:MyLogger:Logging message 623
# INFO:MyLogger:Logging message 624
# INFO:MyLogger:Logging message 625
# INFO:MyLogger:Logging message 626
# INFO:MyLogger:Logging message 627
# INFO:MyLogger:Logging message 628
# INFO:MyLogger:Logging message 629
# INFO:MyLogger:Logging message 630
# INFO:MyLogger:Logging message 631
# INFO:MyLogger:Logging message 632
# INFO:MyLogger:Logging message 633
# INFO:MyLogger:Logging message 634
# INFO:MyLogger:Logging message 635
# INFO:MyLogger:Logging message 636
# INFO:MyLogger:Logging message 637
# INFO:MyLogger:Logging message 638
# INFO:MyLogger:Logging message 639
# INFO:MyLogger:Logging message 640
# INFO:MyLogger:Logging message 641
# INFO:MyLogger:Logging message 642
# INFO:MyLogger:Logging message 643
# INFO:MyLogger:Logging message 644
# INFO:MyLogger:Logging message 645
# INFO:MyLogger:Logging message 646
# INFO:MyLogger:Logging message 647
# INFO:MyLogger:Logging message 648
# INFO:MyLogger:Logging message 649
# INFO:MyLogger:Logging message 650
# INFO:MyLogger:Logging message 651
# INFO:MyLogger:Logging message 652
# INFO:MyLogger:Logging message 653
# INFO:MyLogger:Logging message 654
# INFO:MyLogger:Logging message 655
# INFO:MyLogger:Logging message 656
# INFO:MyLogger:Logging message 657
# INFO:MyLogger:Logging message 658
# INFO:MyLogger:Logging message 659
# INFO:MyLogger:Logging message 660
# INFO:MyLogger:Logging message 661
# INFO:MyLogger:Logging message 662
# INFO:MyLogger:Logging message 663
# INFO:MyLogger:Logging message 664
# INFO:MyLogger:Logging message 665
# INFO:MyLogger:Logging message 666
# INFO:MyLogger:Logging message 667
# INFO:MyLogger:Logging message 668
# INFO:MyLogger:Logging message 669
# INFO:MyLogger:Logging message 670
# INFO:MyLogger:Logging message 671
# INFO:MyLogger:Logging message 672
# INFO:MyLogger:Logging message 673
# INFO:MyLogger:Logging message 674
# INFO:MyLogger:Logging message 675
# INFO:MyLogger:Logging message 676
# INFO:MyLogger:Logging message 677
# INFO:MyLogger:Logging message 678
# INFO:MyLogger:Logging message 679
# INFO:MyLogger:Logging message 680
# INFO:MyLogger:Logging message 681
# INFO:MyLogger:Logging message 682
# INFO:MyLogger:Logging message 683
# INFO:MyLogger:Logging message 684
# INFO:MyLogger:Logging message 685
# INFO:MyLogger:Logging message 686
# INFO:MyLogger:Logging message 687
# INFO:MyLogger:Logging message 688
# INFO:MyLogger:Logging message 689
# INFO:MyLogger:Logging message 690
# INFO:MyLogger:Logging message 691
# INFO:MyLogger:Logging message 692
# INFO:MyLogger:Logging message 693
# INFO:MyLogger:Logging message 694
# INFO:MyLogger:Logging message 695
# INFO:MyLogger:Logging message 696
# INFO:MyLogger:Logging message 697
# INFO:MyLogger:Logging message 698
# INFO:MyLogger:Logging message 699
# INFO:MyLogger:Logging message 700
# INFO:MyLogger:Logging message 701
# INFO:MyLogger:Logging message 702
# INFO:MyLogger:Logging message 703
# INFO:MyLogger:Logging message 704
# INFO:MyLogger:Logging message 705
# INFO:MyLogger:Logging message 706
# INFO:MyLogger:Logging message 707
# INFO:MyLogger:Logging message 708
# INFO:MyLogger:Logging message 709
# INFO:MyLogger:Logging message 710
# INFO:MyLogger:Logging message 711
# INFO:MyLogger:Logging message 712
# INFO:MyLogger:Logging message 713
# INFO:MyLogger:Logging message 714
# INFO:MyLogger:Logging message 715
# INFO:MyLogger:Logging message 716
# INFO:MyLogger:Logging message 717
# INFO:MyLogger:Logging message 718
# INFO:MyLogger:Logging message 719
# INFO:MyLogger:Logging message 720
# INFO:MyLogger:Logging message 721
# INFO:MyLogger:Logging message 722
# INFO:MyLogger:Logging message 723
# INFO:MyLogger:Logging message 724
# INFO:MyLogger:Logging message 725
# INFO:MyLogger:Logging message 726
# INFO:MyLogger:Logging message 727
# INFO:MyLogger:Logging message 728
# INFO:MyLogger:Logging message 729
# INFO:MyLogger:Logging message 730
# INFO:MyLogger:Logging message 731
# INFO:MyLogger:Logging message 732
# INFO:MyLogger:Logging message 733
# INFO:MyLogger:Logging message 734
# INFO:MyLogger:Logging message 735
# INFO:MyLogger:Logging message 736
# INFO:MyLogger:Logging message 737
# INFO:MyLogger:Logging message 738
# INFO:MyLogger:Logging message 739
# INFO:MyLogger:Logging message 740
# INFO:MyLogger:Logging message 741
# INFO:MyLogger:Logging message 742
# INFO:MyLogger:Logging message 743
# INFO:MyLogger:Logging message 744
# INFO:MyLogger:Logging message 745
# INFO:MyLogger:Logging message 746
# INFO:MyLogger:Logging message 747
# INFO:MyLogger:Logging message 748
# INFO:MyLogger:Logging message 749
# INFO:MyLogger:Logging message 750
# INFO:MyLogger:Logging message 751
# INFO:MyLogger:Logging message 752
# INFO:MyLogger:Logging message 753
# INFO:MyLogger:Logging message 754
# INFO:MyLogger:Logging message 755
# INFO:MyLogger:Logging message 756
# INFO:MyLogger:Logging message 757
# INFO:MyLogger:Logging message 758
# INFO:MyLogger:Logging message 759
# INFO:MyLogger:Logging message 760
# INFO:MyLogger:Logging message 761
# INFO:MyLogger:Logging message 762
# INFO:MyLogger:Logging message 763
# INFO:MyLogger:Logging message 764
# INFO:MyLogger:Logging message 765
# INFO:MyLogger:Logging message 766
# INFO:MyLogger:Logging message 767
# INFO:MyLogger:Logging message 768
# INFO:MyLogger:Logging message 769
# INFO:MyLogger:Logging message 770
# INFO:MyLogger:Logging message 771
# INFO:MyLogger:Logging message 772
# INFO:MyLogger:Logging message 773
# INFO:MyLogger:Logging message 774
# INFO:MyLogger:Logging message 775
# INFO:MyLogger:Logging message 776
# INFO:MyLogger:Logging message 777
# INFO:MyLogger:Logging message 778
# INFO:MyLogger:Logging message 779
# INFO:MyLogger:Logging message 780
# INFO:MyLogger:Logging message 781
# INFO:MyLogger:Logging message 782
# INFO:MyLogger:Logging message 783
# INFO:MyLogger:Logging message 784
# INFO:MyLogger:Logging message 785
# INFO:MyLogger:Logging message 786
# INFO:MyLogger:Logging message 787
# INFO:MyLogger:Logging message 788
# INFO:MyLogger:Logging message 789
# INFO:MyLogger:Logging message 790
# INFO:MyLogger:Logging message 791
# INFO:MyLogger:Logging message 792
# INFO:MyLogger:Logging message 793
# INFO:MyLogger:Logging message 794
# INFO:MyLogger:Logging message 795
# INFO:MyLogger:Logging message 796
# INFO:MyLogger:Logging message 797
# INFO:MyLogger:Logging message 798
# INFO:MyLogger:Logging message 799
# INFO:MyLogger:Logging message 800
# INFO:MyLogger:Logging message 801
# INFO:MyLogger:Logging message 802
# INFO:MyLogger:Logging message 803
# INFO:MyLogger:Logging message 804
# INFO:MyLogger:Logging message 805
# INFO:MyLogger:Logging message 806
# INFO:MyLogger:Logging message 807
# INFO:MyLogger:Logging message 808
# INFO:MyLogger:Logging message 809
# INFO:MyLogger:Logging message 810
# INFO:MyLogger:Logging message 811
# INFO:MyLogger:Logging message 812
# INFO:MyLogger:Logging message 813
# INFO:MyLogger:Logging message 814
# INFO:MyLogger:Logging message 815
# INFO:MyLogger:Logging message 816
# INFO:MyLogger:Logging message 817
# INFO:MyLogger:Logging message 818
# INFO:MyLogger:Logging message 819
# INFO:MyLogger:Logging message 820
# INFO:MyLogger:Logging message 821
# INFO:MyLogger:Logging message 822
# INFO:MyLogger:Logging message 823
# INFO:MyLogger:Logging message 824
# INFO:MyLogger:Logging message 825
# INFO:MyLogger:Logging message 826
# INFO:MyLogger:Logging message 827
# INFO:MyLogger:Logging message 828
# INFO:MyLogger:Logging message 829
# INFO:MyLogger:Logging message 830
# INFO:MyLogger:Logging message 831
# INFO:MyLogger:Logging message 832
# INFO:MyLogger:Logging message 833
# INFO:MyLogger:Logging message 834
# INFO:MyLogger:Logging message 835
# INFO:MyLogger:Logging message 836
# INFO:MyLogger:Logging message 837
# INFO:MyLogger:Logging message 838
# INFO:MyLogger:Logging message 839
# INFO:MyLogger:Logging message 840
# INFO:MyLogger:Logging message 841
# INFO:MyLogger:Logging message 842
# INFO:MyLogger:Logging message 843
# INFO:MyLogger:Logging message 844
# INFO:MyLogger:Logging message 845
# INFO:MyLogger:Logging message 846
# INFO:MyLogger:Logging message 847
# INFO:MyLogger:Logging message 848
# INFO:MyLogger:Logging message 849
# INFO:MyLogger:Logging message 850
# INFO:MyLogger:Logging message 851
# INFO:MyLogger:Logging message 852
# INFO:MyLogger:Logging message 853
# INFO:MyLogger:Logging message 854
# INFO:MyLogger:Logging message 855
# INFO:MyLogger:Logging message 856
# INFO:MyLogger:Logging message 857
# INFO:MyLogger:Logging message 858
# INFO:MyLogger:Logging message 859
# INFO:MyLogger:Logging message 860
# INFO:MyLogger:Logging message 861
# INFO:MyLogger:Logging message 862
# INFO:MyLogger:Logging message 863
# INFO:MyLogger:Logging message 864
# INFO:MyLogger:Logging message 865
# INFO:MyLogger:Logging message 866
# INFO:MyLogger:Logging message 867
# INFO:MyLogger:Logging message 868
# INFO:MyLogger:Logging message 869
# INFO:MyLogger:Logging message 870
# INFO:MyLogger:Logging message 871
# INFO:MyLogger:Logging message 872
# INFO:MyLogger:Logging message 873
# INFO:MyLogger:Logging message 874
# INFO:MyLogger:Logging message 875
# INFO:MyLogger:Logging message 876
# INFO:MyLogger:Logging message 877
# INFO:MyLogger:Logging message 878
# INFO:MyLogger:Logging message 879
# INFO:MyLogger:Logging message 880
# INFO:MyLogger:Logging message 881
# INFO:MyLogger:Logging message 882
# INFO:MyLogger:Logging message 883
# INFO:MyLogger:Logging message 884
# INFO:MyLogger:Logging message 885
# INFO:MyLogger:Logging message 886
# INFO:MyLogger:Logging message 887
# INFO:MyLogger:Logging message 888
# INFO:MyLogger:Logging message 889
# INFO:MyLogger:Logging message 890
# INFO:MyLogger:Logging message 891
# INFO:MyLogger:Logging message 892
# INFO:MyLogger:Logging message 893
# INFO:MyLogger:Logging message 894
# INFO:MyLogger:Logging message 895
# INFO:MyLogger:Logging message 896
# INFO:MyLogger:Logging message 897
# INFO:MyLogger:Logging message 898
# INFO:MyLogger:Logging message 899
# INFO:MyLogger:Logging message 900
# INFO:MyLogger:Logging message 901
# INFO:MyLogger:Logging message 902
# INFO:MyLogger:Logging message 903
# INFO:MyLogger:Logging message 904
# INFO:MyLogger:Logging message 905
# INFO:MyLogger:Logging message 906
# INFO:MyLogger:Logging message 907
# INFO:MyLogger:Logging message 908
# INFO:MyLogger:Logging message 909
# INFO:MyLogger:Logging message 910
# INFO:MyLogger:Logging message 911
# INFO:MyLogger:Logging message 912
# INFO:MyLogger:Logging message 913
# INFO:MyLogger:Logging message 914
# INFO:MyLogger:Logging message 915
# INFO:MyLogger:Logging message 916
# INFO:MyLogger:Logging message 917
# INFO:MyLogger:Logging message 918
# INFO:MyLogger:Logging message 919
# INFO:MyLogger:Logging message 920
# INFO:MyLogger:Logging message 921
# INFO:MyLogger:Logging message 922
# INFO:MyLogger:Logging message 923
# INFO:MyLogger:Logging message 924
# INFO:MyLogger:Logging message 925
# INFO:MyLogger:Logging message 926
# INFO:MyLogger:Logging message 927
# INFO:MyLogger:Logging message 928
# INFO:MyLogger:Logging message 929
# INFO:MyLogger:Logging message 930
# INFO:MyLogger:Logging message 931
# INFO:MyLogger:Logging message 932
# INFO:MyLogger:Logging message 933
# INFO:MyLogger:Logging message 934
# INFO:MyLogger:Logging message 935
# INFO:MyLogger:Logging message 936
# INFO:MyLogger:Logging message 937
# INFO:MyLogger:Logging message 938
# INFO:MyLogger:Logging message 939
# INFO:MyLogger:Logging message 940
# INFO:MyLogger:Logging message 941
# INFO:MyLogger:Logging message 942
# INFO:MyLogger:Logging message 943
# INFO:MyLogger:Logging message 944
# INFO:MyLogger:Logging message 945
# INFO:MyLogger:Logging message 946
# INFO:MyLogger:Logging message 947
# INFO:MyLogger:Logging message 948
# INFO:MyLogger:Logging message 949
# INFO:MyLogger:Logging message 950
# INFO:MyLogger:Logging message 951
# INFO:MyLogger:Logging message 952
# INFO:MyLogger:Logging message 953
# INFO:MyLogger:Logging message 954
# INFO:MyLogger:Logging message 955
# INFO:MyLogger:Logging message 956
# INFO:MyLogger:Logging message 957
# INFO:MyLogger:Logging message 958
# INFO:MyLogger:Logging message 959
# INFO:MyLogger:Logging message 960
# INFO:MyLogger:Logging message 961
# INFO:MyLogger:Logging message 962
# INFO:MyLogger:Logging message 963
# INFO:MyLogger:Logging message 964
# INFO:MyLogger:Logging message 965
# INFO:MyLogger:Logging message 966
# INFO:MyLogger:Logging message 967
# INFO:MyLogger:Logging message 968
# INFO:MyLogger:Logging message 969
# INFO:MyLogger:Logging message 970
# INFO:MyLogger:Logging message 971
# INFO:MyLogger:Logging message 972
# INFO:MyLogger:Logging message 973
# INFO:MyLogger:Logging message 974
# INFO:MyLogger:Logging message 975
# INFO:MyLogger:Logging message 976
# INFO:MyLogger:Logging message 977
# INFO:MyLogger:Logging message 978
# INFO:MyLogger:Logging message 979
# INFO:MyLogger:Logging message 980
# INFO:MyLogger:Logging message 981
# INFO:MyLogger:Logging message 982
# INFO:MyLogger:Logging message 983
# INFO:MyLogger:Logging message 984
# INFO:MyLogger:Logging message 985
# INFO:MyLogger:Logging message 986
# INFO:MyLogger:Logging message 987
# INFO:MyLogger:Logging message 988
# INFO:MyLogger:Logging message 989
# INFO:MyLogger:Logging message 990
# INFO:MyLogger:Logging message 991
# INFO:MyLogger:Logging message 992
# INFO:MyLogger:Logging message 993
# INFO:MyLogger:Logging message 994
# INFO:MyLogger:Logging message 995
# INFO:MyLogger:Logging message 996
# INFO:MyLogger:Logging message 997
# INFO:MyLogger:Logging message 998
# INFO:MyLogger:Logging message 999
# INFO:MyLogger:Logging message 1000
# INFO:MyLogger:Logging message 1001
# INFO:MyLogger:Logging message 1002
# INFO:MyLogger:Logging message 1003
# INFO:MyLogger:Logging message 1004
# INFO:MyLogger:Logging message 1005
# INFO:MyLogger:Logging message 1006
# INFO:MyLogger:Logging message 1007
# INFO:MyLogger:Logging message 1008
# INFO:MyLogger:Logging message 1009
# INFO:MyLogger:Logging message 1010
# INFO:MyLogger:Logging message 1011
# INFO:MyLogger:Logging message 1012
# INFO:MyLogger:Logging message 1013
# INFO:MyLogger:Logging message 1014
# INFO:MyLogger:Logging message 1015
# INFO:MyLogger:Logging message 1016
# INFO:MyLogger:Logging message 1017
# INFO:MyLogger:Logging message 1018
# INFO:MyLogger:Logging message 1019
# INFO:MyLogger:Logging message 1020
# INFO:MyLogger:Logging message 1021
# INFO:MyLogger:Logging message 1022
# INFO:MyLogger:Logging message 1023
# INFO:MyLogger:Logging message 1024
# INFO:MyLogger:Logging message 1025
# INFO:MyLogger:Logging message 1026
# INFO:MyLogger:Logging message 1027
# INFO:MyLogger:Logging message 1028
# INFO:MyLogger:Logging message 1029
# INFO:MyLogger:Logging message 1030
# INFO:MyLogger:Logging message 1031
# INFO:MyLogger:Logging message 1032
# INFO:MyLogger:Logging message 1033
# INFO:MyLogger:Logging message 1034
# INFO:MyLogger:Logging message 1035
# INFO:MyLogger:Logging message 1036
# INFO:MyLogger:Logging message 1037
# INFO:MyLogger:Logging message 1038
# INFO:MyLogger:Logging message 1039
# INFO:MyLogger:Logging message 1040
# INFO:MyLogger:Logging message 1041
# INFO:MyLogger:Logging message 1042
# INFO:MyLogger:Logging message 1043
# INFO:MyLogger:Logging message 1044
# INFO:MyLogger:Logging message 1045
# INFO:MyLogger:Logging message 1046
# INFO:MyLogger:Logging message 1047
# INFO:MyLogger:Logging message 1048
# INFO:MyLogger:Logging message 1049
# INFO:MyLogger:Logging message 1050
# INFO:MyLogger:Logging message 1051
# INFO:MyLogger:Logging message 1052
# INFO:MyLogger:Logging message 1053
# INFO:MyLogger:Logging message 1054
# INFO:MyLogger:Logging message 1055
# INFO:MyLogger:Logging message 1056
# INFO:MyLogger:Logging message 1057
# INFO:MyLogger:Logging message 1058
# INFO:MyLogger:Logging message 1059
# INFO:MyLogger:Logging message 1060
# INFO:MyLogger:Logging message 1061
# INFO:MyLogger:Logging message 1062
# INFO:MyLogger:Logging message 1063
# INFO:MyLogger:Logging message 1064
# INFO:MyLogger:Logging message 1065
# INFO:MyLogger:Logging message 1066
# INFO:MyLogger:Logging message 1067
# INFO:MyLogger:Logging message 1068
# INFO:MyLogger:Logging message 1069
# INFO:MyLogger:Logging message 1070
# INFO:MyLogger:Logging message 1071
# INFO:MyLogger:Logging message 1072
# INFO:MyLogger:Logging message 1073
# INFO:MyLogger:Logging message 1074
# INFO:MyLogger:Logging message 1075
# INFO:MyLogger:Logging message 1076
# INFO:MyLogger:Logging message 1077
# INFO:MyLogger:Logging message 1078
# INFO:MyLogger:Logging message 1079
# INFO:MyLogger:Logging message 1080
# INFO:MyLogger:Logging message 1081
# INFO:MyLogger:Logging message 1082
# INFO:MyLogger:Logging message 1083
# INFO:MyLogger:Logging message 1084
# INFO:MyLogger:Logging message 1085
# INFO:MyLogger:Logging message 1086
# INFO:MyLogger:Logging message 1087
# INFO:MyLogger:Logging message 1088
# INFO:MyLogger:Logging message 1089
# INFO:MyLogger:Logging message 1090
# INFO:MyLogger:Logging message 1091
# INFO:MyLogger:Logging message 1092
# INFO:MyLogger:Logging message 1093
# INFO:MyLogger:Logging message 1094
# INFO:MyLogger:Logging message 1095
# INFO:MyLogger:Logging message 1096
# INFO:MyLogger:Logging message 1097
# INFO:MyLogger:Logging message 1098
# INFO:MyLogger:Logging message 1099
# INFO:MyLogger:Logging message 1100
# INFO:MyLogger:Logging message 1101
# INFO:MyLogger:Logging message 1102
# INFO:MyLogger:Logging message 1103
# INFO:MyLogger:Logging message 1104
# INFO:MyLogger:Logging message 1105
# INFO:MyLogger:Logging message 1106
# INFO:MyLogger:Logging message 1107
# INFO:MyLogger:Logging message 1108
# INFO:MyLogger:Logging message 1109
# INFO:MyLogger:Logging message 1110
# INFO:MyLogger:Logging message 1111
# INFO:MyLogger:Logging message 1112
# INFO:MyLogger:Logging message 1113
# INFO:MyLogger:Logging message 1114
# INFO:MyLogger:Logging message 1115
# INFO:MyLogger:Logging message 1116
# INFO:MyLogger:Logging message 1117
# INFO:MyLogger:Logging message 1118
# INFO:MyLogger:Logging message 1119
# INFO:MyLogger:Logging message 1120
# INFO:MyLogger:Logging message 1121
# INFO:MyLogger:Logging message 1122
# INFO:MyLogger:Logging message 1123
# INFO:MyLogger:Logging message 1124
# INFO:MyLogger:Logging message 1125
# INFO:MyLogger:Logging message 1126
# INFO:MyLogger:Logging message 1127
# INFO:MyLogger:Logging message 1128
# INFO:MyLogger:Logging message 1129
# INFO:MyLogger:Logging message 1130
# INFO:MyLogger:Logging message 1131
# INFO:MyLogger:Logging message 1132
# INFO:MyLogger:Logging message 1133
# INFO:MyLogger:Logging message 1134
# INFO:MyLogger:Logging message 1135
# INFO:MyLogger:Logging message 1136
# INFO:MyLogger:Logging message 1137
# INFO:MyLogger:Logging message 1138
# INFO:MyLogger:Logging message 1139
# INFO:MyLogger:Logging message 1140
# INFO:MyLogger:Logging message 1141
# INFO:MyLogger:Logging message 1142
# INFO:MyLogger:Logging message 1143
# INFO:MyLogger:Logging message 1144
# INFO:MyLogger:Logging message 1145
# INFO:MyLogger:Logging message 1146
# INFO:MyLogger:Logging message 1147
# INFO:MyLogger:Logging message 1148
# INFO:MyLogger:Logging message 1149
# INFO:MyLogger:Logging message 1150
# INFO:MyLogger:Logging message 1151
# INFO:MyLogger:Logging message 1152
# INFO:MyLogger:Logging message 1153
# INFO:MyLogger:Logging message 1154
# INFO:MyLogger:Logging message 1155
# INFO:MyLogger:Logging message 1156
# INFO:MyLogger:Logging message 1157
# INFO:MyLogger:Logging message 1158
# INFO:MyLogger:Logging message 1159
# INFO:MyLogger:Logging message 1160
# INFO:MyLogger:Logging message 1161
# INFO:MyLogger:Logging message 1162
# INFO:MyLogger:Logging message 1163
# INFO:MyLogger:Logging message 1164
# INFO:MyLogger:Logging message 1165
# INFO:MyLogger:Logging message 1166
# INFO:MyLogger:Logging message 1167
# INFO:MyLogger:Logging message 1168
# INFO:MyLogger:Logging message 1169
# INFO:MyLogger:Logging message 1170
# INFO:MyLogger:Logging message 1171
# INFO:MyLogger:Logging message 1172
# INFO:MyLogger:Logging message 1173
# INFO:MyLogger:Logging message 1174
# INFO:MyLogger:Logging message 1175
# INFO:MyLogger:Logging message 1176
# INFO:MyLogger:Logging message 1177
# INFO:MyLogger:Logging message 1178
# INFO:MyLogger:Logging message 1179
# INFO:MyLogger:Logging message 1180
# INFO:MyLogger:Logging message 1181
# INFO:MyLogger:Logging message 1182
# INFO:MyLogger:Logging message 1183
# INFO:MyLogger:Logging message 1184
# INFO:MyLogger:Logging message 1185
# INFO:MyLogger:Logging message 1186
# INFO:MyLogger:Logging message 1187
# INFO:MyLogger:Logging message 1188
# INFO:MyLogger:Logging message 1189
# INFO:MyLogger:Logging message 1190
# INFO:MyLogger:Logging message 1191
# INFO:MyLogger:Logging message 1192
# INFO:MyLogger:Logging message 1193
# INFO:MyLogger:Logging message 1194
# INFO:MyLogger:Logging message 1195
# INFO:MyLogger:Logging message 1196
# INFO:MyLogger:Logging message 1197
# INFO:MyLogger:Logging message 1198
# INFO:MyLogger:Logging message 1199
# INFO:MyLogger:Logging message 1200
# INFO:MyLogger:Logging message 1201
# INFO:MyLogger:Logging message 1202
# INFO:MyLogger:Logging message 1203
# INFO:MyLogger:Logging message 1204
# INFO:MyLogger:Logging message 1205
# INFO:MyLogger:Logging message 1206
# INFO:MyLogger:Logging message 1207
# INFO:MyLogger:Logging message 1208
# INFO:MyLogger:Logging message 1209
# INFO:MyLogger:Logging message 1210
# INFO:MyLogger:Logging message 1211
# INFO:MyLogger:Logging message 1212
# INFO:MyLogger:Logging message 1213
# INFO:MyLogger:Logging message 1214
# INFO:MyLogger:Logging message 1215
# INFO:MyLogger:Logging message 1216
# INFO:MyLogger:Logging message 1217
# INFO:MyLogger:Logging message 1218
# INFO:MyLogger:Logging message 1219
# INFO:MyLogger:Logging message 1220
# INFO:MyLogger:Logging message 1221
# INFO:MyLogger:Logging message 1222
# INFO:MyLogger:Logging message 1223
# INFO:MyLogger:Logging message 1224
# INFO:MyLogger:Logging message 1225
# INFO:MyLogger:Logging message 1226
# INFO:MyLogger:Logging message 1227
# INFO:MyLogger:Logging message 1228
# INFO:MyLogger:Logging message 1229
# INFO:MyLogger:Logging message 1230
# INFO:MyLogger:Logging message 1231
# INFO:MyLogger:Logging message 1232
# INFO:MyLogger:Logging message 1233
# INFO:MyLogger:Logging message 1234
# INFO:MyLogger:Logging message 1235
# INFO:MyLogger:Logging message 1236
# INFO:MyLogger:Logging message 1237
# INFO:MyLogger:Logging message 1238
# INFO:MyLogger:Logging message 1239
# INFO:MyLogger:Logging message 1240
# INFO:MyLogger:Logging message 1241
# INFO:MyLogger:Logging message 1242
# INFO:MyLogger:Logging message 1243
# INFO:MyLogger:Logging message 1244
# INFO:MyLogger:Logging message 1245
# INFO:MyLogger:Logging message 1246
# INFO:MyLogger:Logging message 1247
# INFO:MyLogger:Logging message 1248
# INFO:MyLogger:Logging message 1249
# INFO:MyLogger:Logging message 1250
# INFO:MyLogger:Logging message 1251
# INFO:MyLogger:Logging message 1252
# INFO:MyLogger:Logging message 1253
# INFO:MyLogger:Logging message 1254
# INFO:MyLogger:Logging message 1255
# INFO:MyLogger:Logging message 1256
# INFO:MyLogger:Logging message 1257
# INFO:MyLogger:Logging message 1258
# INFO:MyLogger:Logging message 1259
# INFO:MyLogger:Logging message 1260
# INFO:MyLogger:Logging message 1261
# INFO:MyLogger:Logging message 1262
# INFO:MyLogger:Logging message 1263
# INFO:MyLogger:Logging message 1264
# INFO:MyLogger:Logging message 1265
# INFO:MyLogger:Logging message 1266
# INFO:MyLogger:Logging message 1267
# INFO:MyLogger:Logging message 1268
# INFO:MyLogger:Logging message 1269
# INFO:MyLogger:Logging message 1270
# INFO:MyLogger:Logging message 1271
# INFO:MyLogger:Logging message 1272
# INFO:MyLogger:Logging message 1273
# INFO:MyLogger:Logging message 1274
# INFO:MyLogger:Logging message 1275
# INFO:MyLogger:Logging message 1276
# INFO:MyLogger:Logging message 1277
# INFO:MyLogger:Logging message 1278
# INFO:MyLogger:Logging message 1279
# INFO:MyLogger:Logging message 1280
# INFO:MyLogger:Logging message 1281
# INFO:MyLogger:Logging message 1282
# INFO:MyLogger:Logging message 1283
# INFO:MyLogger:Logging message 1284
# INFO:MyLogger:Logging message 1285
# INFO:MyLogger:Logging message 1286
# INFO:MyLogger:Logging message 1287
# INFO:MyLogger:Logging message 1288
# INFO:MyLogger:Logging message 1289
# INFO:MyLogger:Logging message 1290
# INFO:MyLogger:Logging message 1291
# INFO:MyLogger:Logging message 1292
# INFO:MyLogger:Logging message 1293
# INFO:MyLogger:Logging message 1294
# INFO:MyLogger:Logging message 1295
# INFO:MyLogger:Logging message 1296
# INFO:MyLogger:Logging message 1297
# INFO:MyLogger:Logging message 1298
# INFO:MyLogger:Logging message 1299
# INFO:MyLogger:Logging message 1300
# INFO:MyLogger:Logging message 1301
# INFO:MyLogger:Logging message 1302
# INFO:MyLogger:Logging message 1303
# INFO:MyLogger:Logging message 1304
# INFO:MyLogger:Logging message 1305
# INFO:MyLogger:Logging message 1306
# INFO:MyLogger:Logging message 1307
# INFO:MyLogger:Logging message 1308
# INFO:MyLogger:Logging message 1309
# INFO:MyLogger:Logging message 1310
# INFO:MyLogger:Logging message 1311
# INFO:MyLogger:Logging message 1312
# INFO:MyLogger:Logging message 1313
# INFO:MyLogger:Logging message 1314
# INFO:MyLogger:Logging message 1315
# INFO:MyLogger:Logging message 1316
# INFO:MyLogger:Logging message 1317
# INFO:MyLogger:Logging message 1318
# INFO:MyLogger:Logging message 1319
# INFO:MyLogger:Logging message 1320
# INFO:MyLogger:Logging message 1321
# INFO:MyLogger:Logging message 1322
# INFO:MyLogger:Logging message 1323
# INFO:MyLogger:Logging message 1324
# INFO:MyLogger:Logging message 1325
# INFO:MyLogger:Logging message 1326
# INFO:MyLogger:Logging message 1327
# INFO:MyLogger:Logging message 1328
# INFO:MyLogger:Logging message 1329
# INFO:MyLogger:Logging message 1330
# INFO:MyLogger:Logging message 1331
# INFO:MyLogger:Logging message 1332
# INFO:MyLogger:Logging message 1333
# INFO:MyLogger:Logging message 1334
# INFO:MyLogger:Logging message 1335
# INFO:MyLogger:Logging message 1336
# INFO:MyLogger:Logging message 1337
# INFO:MyLogger:Logging message 1338
# INFO:MyLogger:Logging message 1339
# INFO:MyLogger:Logging message 1340
# INFO:MyLogger:Logging message 1341
# INFO:MyLogger:Logging message 1342
# INFO:MyLogger:Logging message 1343
# INFO:MyLogger:Logging message 1344
# INFO:MyLogger:Logging message 1345
# INFO:MyLogger:Logging message 1346
# INFO:MyLogger:Logging message 1347
# INFO:MyLogger:Logging message 1348
# INFO:MyLogger:Logging message 1349
# INFO:MyLogger:Logging message 1350
# INFO:MyLogger:Logging message 1351
# INFO:MyLogger:Logging message 1352
# INFO:MyLogger:Logging message 1353
# INFO:MyLogger:Logging message 1354
# INFO:MyLogger:Logging message 1355
# INFO:MyLogger:Logging message 1356
# INFO:MyLogger:Logging message 1357
# INFO:MyLogger:Logging message 1358
# INFO:MyLogger:Logging message 1359
# INFO:MyLogger:Logging message 1360
# INFO:MyLogger:Logging message 1361
# INFO:MyLogger:Logging message 1362
# INFO:MyLogger:Logging message 1363
# INFO:MyLogger:Logging message 1364
# INFO:MyLogger:Logging message 1365
# INFO:MyLogger:Logging message 1366
# INFO:MyLogger:Logging message 1367
# INFO:MyLogger:Logging message 1368
# INFO:MyLogger:Logging message 1369
# INFO:MyLogger:Logging message 1370
# INFO:MyLogger:Logging message 1371
# INFO:MyLogger:Logging message 1372
# INFO:MyLogger:Logging message 1373
# INFO:MyLogger:Logging message 1374
# INFO:MyLogger:Logging message 1375
# INFO:MyLogger:Logging message 1376
# INFO:MyLogger:Logging message 1377
# INFO:MyLogger:Logging message 1378
# INFO:MyLogger:Logging message 1379
# INFO:MyLogger:Logging message 1380
# INFO:MyLogger:Logging message 1381
# INFO:MyLogger:Logging message 1382
# INFO:MyLogger:Logging message 1383
# INFO:MyLogger:Logging message 1384
# INFO:MyLogger:Logging message 1385
# INFO:MyLogger:Logging message 1386
# INFO:MyLogger:Logging message 1387
# INFO:MyLogger:Logging message 1388
# INFO:MyLogger:Logging message 1389
# INFO:MyLogger:Logging message 1390
# INFO:MyLogger:Logging message 1391
# INFO:MyLogger:Logging message 1392
# INFO:MyLogger:Logging message 1393
# INFO:MyLogger:Logging message 1394
# INFO:MyLogger:Logging message 1395
# INFO:MyLogger:Logging message 1396
# INFO:MyLogger:Logging message 1397
# INFO:MyLogger:Logging message 1398
# INFO:MyLogger:Logging message 1399
# INFO:MyLogger:Logging message 1400
# INFO:MyLogger:Logging message 1401
# INFO:MyLogger:Logging message 1402
# ...
# INFO:MyLogger:Logging message 4543
# INFO:MyLogger:Logging message 4544
# INFO:MyLogger:Logging message 4545
# INFO:MyLogger:Logging message 4546
# INFO:MyLogger:Logging message 4547
# INFO:MyLogger:Logging message 4548
# INFO:MyLogger:Logging message 4549
# INFO:MyLogger:Logging message 4550
# INFO:MyLogger:Logging message 4551
# INFO:MyLogger:Logging message 4552
# INFO:MyLogger:Logging message 4553
# INFO:MyLogger:Logging message 4554
# INFO:MyLogger:Logging message 4555
# INFO:MyLogger:Logging message 4556
# INFO:MyLogger:Logging message 4557
# INFO:MyLogger:Logging message 4558
# INFO:MyLogger:Logging message 4559
# INFO:MyLogger:Logging message 4560
# INFO:MyLogger:Logging message 4561
# INFO:MyLogger:Logging message 4562
# INFO:MyLogger:Logging message 4563
# INFO:MyLogger:Logging message 4564
# INFO:MyLogger:Logging message 4565
# INFO:MyLogger:Logging message 4566
# INFO:MyLogger:Logging message 4567
# INFO:MyLogger:Logging message 4568
# INFO:MyLogger:Logging message 4569
# INFO:MyLogger:Logging message 4570
# INFO:MyLogger:Logging message 4571
# INFO:MyLogger:Logging message 4572
# INFO:MyLogger:Logging message 4573
# INFO:MyLogger:Logging message 4574
# INFO:MyLogger:Logging message 4575
# INFO:MyLogger:Logging message 4576
# INFO:MyLogger:Logging message 4577
# INFO:MyLogger:Logging message 4578
# INFO:MyLogger:Logging message 4579
# INFO:MyLogger:Logging message 4580
# INFO:MyLogger:Logging message 4581
# INFO:MyLogger:Logging message 4582
# INFO:MyLogger:Logging message 4583
# INFO:MyLogger:Logging message 4584
# INFO:MyLogger:Logging message 4585
# INFO:MyLogger:Logging message 4586
# INFO:MyLogger:Logging message 4587
# INFO:MyLogger:Logging message 4588
# INFO:MyLogger:Logging message 4589
# INFO:MyLogger:Logging message 4590
# INFO:MyLogger:Logging message 4591
# INFO:MyLogger:Logging message 4592
# INFO:MyLogger:Logging message 4593
# INFO:MyLogger:Logging message 4594
# INFO:MyLogger:Logging message 4595
# INFO:MyLogger:Logging message 4596
# INFO:MyLogger:Logging message 4597
# INFO:MyLogger:Logging message 4598
# INFO:MyLogger:Logging message 4599
# INFO:MyLogger:Logging message 4600
# INFO:MyLogger:Logging message 4601
# INFO:MyLogger:Logging message 4602
# INFO:MyLogger:Logging message 4603
# INFO:MyLogger:Logging message 4604
# INFO:MyLogger:Logging message 4605
# INFO:MyLogger:Logging message 4606
# INFO:MyLogger:Logging message 4607
# INFO:MyLogger:Logging message 4608
# INFO:MyLogger:Logging message 4609
# INFO:MyLogger:Logging message 4610
# INFO:MyLogger:Logging message 4611
# INFO:MyLogger:Logging message 4612
# INFO:MyLogger:Logging message 4613
# INFO:MyLogger:Logging message 4614
# INFO:MyLogger:Logging message 4615
# INFO:MyLogger:Logging message 4616
# INFO:MyLogger:Logging message 4617
# INFO:MyLogger:Logging message 4618
# INFO:MyLogger:Logging message 4619
# INFO:MyLogger:Logging message 4620
# INFO:MyLogger:Logging message 4621
# INFO:MyLogger:Logging message 4622
# INFO:MyLogger:Logging message 4623
# INFO:MyLogger:Logging message 4624
# INFO:MyLogger:Logging message 4625
# INFO:MyLogger:Logging message 4626
# INFO:MyLogger:Logging message 4627
# INFO:MyLogger:Logging message 4628
# INFO:MyLogger:Logging message 4629
# INFO:MyLogger:Logging message 4630
# INFO:MyLogger:Logging message 4631
# INFO:MyLogger:Logging message 4632
# INFO:MyLogger:Logging message 4633
# INFO:MyLogger:Logging message 4634
# INFO:MyLogger:Logging message 4635
# INFO:MyLogger:Logging message 4636
# INFO:MyLogger:Logging message 4637
# INFO:MyLogger:Logging message 4638
# INFO:MyLogger:Logging message 4639
# INFO:MyLogger:Logging message 4640
# INFO:MyLogger:Logging message 4641
# INFO:MyLogger:Logging message 4642
# INFO:MyLogger:Logging message 4643
# INFO:MyLogger:Logging message 4644
# INFO:MyLogger:Logging message 4645
# INFO:MyLogger:Logging message 4646
# INFO:MyLogger:Logging message 4647
# INFO:MyLogger:Logging message 4648
# INFO:MyLogger:Logging message 4649
# INFO:MyLogger:Logging message 4650
# INFO:MyLogger:Logging message 4651
# INFO:MyLogger:Logging message 4652
# INFO:MyLogger:Logging message 4653
# INFO:MyLogger:Logging message 4654
# INFO:MyLogger:Logging message 4655
# INFO:MyLogger:Logging message 4656
# INFO:MyLogger:Logging message 4657
# INFO:MyLogger:Logging message 4658
# INFO:MyLogger:Logging message 4659
# INFO:MyLogger:Logging message 4660
# INFO:MyLogger:Logging message 4661
# INFO:MyLogger:Logging message 4662
# INFO:MyLogger:Logging message 4663
# INFO:MyLogger:Logging message 4664
# INFO:MyLogger:Logging message 4665
# INFO:MyLogger:Logging message 4666
# INFO:MyLogger:Logging message 4667
# INFO:MyLogger:Logging message 4668
# INFO:MyLogger:Logging message 4669
# INFO:MyLogger:Logging message 4670
# INFO:MyLogger:Logging message 4671
# INFO:MyLogger:Logging message 4672
# INFO:MyLogger:Logging message 4673
# INFO:MyLogger:Logging message 4674
# INFO:MyLogger:Logging message 4675
# INFO:MyLogger:Logging message 4676
# INFO:MyLogger:Logging message 4677
# INFO:MyLogger:Logging message 4678
# INFO:MyLogger:Logging message 4679
# INFO:MyLogger:Logging message 4680
# INFO:MyLogger:Logging message 4681
# INFO:MyLogger:Logging message 4682
# INFO:MyLogger:Logging message 4683
# INFO:MyLogger:Logging message 4684
# INFO:MyLogger:Logging message 4685
# INFO:MyLogger:Logging message 4686
# INFO:MyLogger:Logging message 4687
# INFO:MyLogger:Logging message 4688
# INFO:MyLogger:Logging message 4689
# INFO:MyLogger:Logging message 4690
# INFO:MyLogger:Logging message 4691
# INFO:MyLogger:Logging message 4692
# INFO:MyLogger:Logging message 4693
# INFO:MyLogger:Logging message 4694
# INFO:MyLogger:Logging message 4695
# INFO:MyLogger:Logging message 4696
# INFO:MyLogger:Logging message 4697
# INFO:MyLogger:Logging message 4698
# INFO:MyLogger:Logging message 4699
# INFO:MyLogger:Logging message 4700
# INFO:MyLogger:Logging message 4701
# INFO:MyLogger:Logging message 4702
# INFO:MyLogger:Logging message 4703
# INFO:MyLogger:Logging message 4704
# INFO:MyLogger:Logging message 4705
# INFO:MyLogger:Logging message 4706
# INFO:MyLogger:Logging message 4707
# INFO:MyLogger:Logging message 4708
# INFO:MyLogger:Logging message 4709
# INFO:MyLogger:Logging message 4710
# INFO:MyLogger:Logging message 4711
# INFO:MyLogger:Logging message 4712
# INFO:MyLogger:Logging message 4713
# INFO:MyLogger:Logging message 4714
# INFO:MyLogger:Logging message 4715
# INFO:MyLogger:Logging message 4716
# INFO:MyLogger:Logging message 4717
# INFO:MyLogger:Logging message 4718
# INFO:MyLogger:Logging message 4719
# INFO:MyLogger:Logging message 4720
# INFO:MyLogger:Logging message 4721
# INFO:MyLogger:Logging message 4722
# INFO:MyLogger:Logging message 4723
# INFO:MyLogger:Logging message 4724
# INFO:MyLogger:Logging message 4725
# INFO:MyLogger:Logging message 4726
# INFO:MyLogger:Logging message 4727
# INFO:MyLogger:Logging message 4728
# INFO:MyLogger:Logging message 4729
# INFO:MyLogger:Logging message 4730
# INFO:MyLogger:Logging message 4731
# INFO:MyLogger:Logging message 4732
# INFO:MyLogger:Logging message 4733
# INFO:MyLogger:Logging message 4734
# INFO:MyLogger:Logging message 4735
# INFO:MyLogger:Logging message 4736
# INFO:MyLogger:Logging message 4737
# INFO:MyLogger:Logging message 4738
# INFO:MyLogger:Logging message 4739
# INFO:MyLogger:Logging message 4740
# INFO:MyLogger:Logging message 4741
# INFO:MyLogger:Logging message 4742
# INFO:MyLogger:Logging message 4743
# INFO:MyLogger:Logging message 4744
# INFO:MyLogger:Logging message 4745
# INFO:MyLogger:Logging message 4746
# INFO:MyLogger:Logging message 4747
# INFO:MyLogger:Logging message 4748
# INFO:MyLogger:Logging message 4749
# INFO:MyLogger:Logging message 4750
# INFO:MyLogger:Logging message 4751
# INFO:MyLogger:Logging message 4752
# INFO:MyLogger:Logging message 4753
# INFO:MyLogger:Logging message 4754
# INFO:MyLogger:Logging message 4755
# INFO:MyLogger:Logging message 4756
# INFO:MyLogger:Logging message 4757
# INFO:MyLogger:Logging message 4758
# INFO:MyLogger:Logging message 4759
# INFO:MyLogger:Logging message 4760
# INFO:MyLogger:Logging message 4761
# INFO:MyLogger:Logging message 4762
# INFO:MyLogger:Logging message 4763
# INFO:MyLogger:Logging message 4764
# INFO:MyLogger:Logging message 4765
# INFO:MyLogger:Logging message 4766
# INFO:MyLogger:Logging message 4767
# INFO:MyLogger:Logging message 4768
# INFO:MyLogger:Logging message 4769
# INFO:MyLogger:Logging message 4770
# INFO:MyLogger:Logging message 4771
# INFO:MyLogger:Logging message 4772
# INFO:MyLogger:Logging message 4773
# INFO:MyLogger:Logging message 4774
# INFO:MyLogger:Logging message 4775
# INFO:MyLogger:Logging message 4776
# INFO:MyLogger:Logging message 4777
# INFO:MyLogger:Logging message 4778
# INFO:MyLogger:Logging message 4779
# INFO:MyLogger:Logging message 4780
# INFO:MyLogger:Logging message 4781
# INFO:MyLogger:Logging message 4782
# INFO:MyLogger:Logging message 4783
# INFO:MyLogger:Logging message 4784
# INFO:MyLogger:Logging message 4785
# INFO:MyLogger:Logging message 4786
# INFO:MyLogger:Logging message 4787
# INFO:MyLogger:Logging message 4788
# INFO:MyLogger:Logging message 4789
# INFO:MyLogger:Logging message 4790
# INFO:MyLogger:Logging message 4791
# INFO:MyLogger:Logging message 4792
# INFO:MyLogger:Logging message 4793
# INFO:MyLogger:Logging message 4794
# INFO:MyLogger:Logging message 4795
# INFO:MyLogger:Logging message 4796
# INFO:MyLogger:Logging message 4797
# INFO:MyLogger:Logging message 4798
# INFO:MyLogger:Logging message 4799
# INFO:MyLogger:Logging message 4800
# INFO:MyLogger:Logging message 4801
# INFO:MyLogger:Logging message 4802
# INFO:MyLogger:Logging message 4803
# INFO:MyLogger:Logging message 4804
# INFO:MyLogger:Logging message 4805
# INFO:MyLogger:Logging message 4806
# INFO:MyLogger:Logging message 4807
# INFO:MyLogger:Logging message 4808
# INFO:MyLogger:Logging message 4809
# INFO:MyLogger:Logging message 4810
# INFO:MyLogger:Logging message 4811
# INFO:MyLogger:Logging message 4812
# INFO:MyLogger:Logging message 4813
# INFO:MyLogger:Logging message 4814
# INFO:MyLogger:Logging message 4815
# INFO:MyLogger:Logging message 4816
# INFO:MyLogger:Logging message 4817
# INFO:MyLogger:Logging message 4818
# INFO:MyLogger:Logging message 4819
# INFO:MyLogger:Logging message 4820
# INFO:MyLogger:Logging message 4821
# INFO:MyLogger:Logging message 4822
# INFO:MyLogger:Logging message 4823
# INFO:MyLogger:Logging message 4824
# INFO:MyLogger:Logging message 4825
# INFO:MyLogger:Logging message 4826
# INFO:MyLogger:Logging message 4827
# INFO:MyLogger:Logging message 4828
# INFO:MyLogger:Logging message 4829
# INFO:MyLogger:Logging message 4830
# INFO:MyLogger:Logging message 4831
# INFO:MyLogger:Logging message 4832
# INFO:MyLogger:Logging message 4833
# INFO:MyLogger:Logging message 4834
# INFO:MyLogger:Logging message 4835
# INFO:MyLogger:Logging message 4836
# INFO:MyLogger:Logging message 4837
# INFO:MyLogger:Logging message 4838
# INFO:MyLogger:Logging message 4839
# INFO:MyLogger:Logging message 4840
# INFO:MyLogger:Logging message 4841
# INFO:MyLogger:Logging message 4842
# INFO:MyLogger:Logging message 4843
# INFO:MyLogger:Logging message 4844
# INFO:MyLogger:Logging message 4845
# INFO:MyLogger:Logging message 4846
# INFO:MyLogger:Logging message 4847
# INFO:MyLogger:Logging message 4848
# INFO:MyLogger:Logging message 4849
# INFO:MyLogger:Logging message 4850
# INFO:MyLogger:Logging message 4851
# INFO:MyLogger:Logging message 4852
# INFO:MyLogger:Logging message 4853
# INFO:MyLogger:Logging message 4854
# INFO:MyLogger:Logging message 4855
# INFO:MyLogger:Logging message 4856
# INFO:MyLogger:Logging message 4857
# INFO:MyLogger:Logging message 4858
# INFO:MyLogger:Logging message 4859
# INFO:MyLogger:Logging message 4860
# INFO:MyLogger:Logging message 4861
# INFO:MyLogger:Logging message 4862
# INFO:MyLogger:Logging message 4863
# INFO:MyLogger:Logging message 4864
# INFO:MyLogger:Logging message 4865
# INFO:MyLogger:Logging message 4866
# INFO:MyLogger:Logging message 4867
# INFO:MyLogger:Logging message 4868
# INFO:MyLogger:Logging message 4869
# INFO:MyLogger:Logging message 4870
# INFO:MyLogger:Logging message 4871
# INFO:MyLogger:Logging message 4872
# INFO:MyLogger:Logging message 4873
# INFO:MyLogger:Logging message 4874
# INFO:MyLogger:Logging message 4875
# INFO:MyLogger:Logging message 4876
# INFO:MyLogger:Logging message 4877
# INFO:MyLogger:Logging message 4878
# INFO:MyLogger:Logging message 4879
# INFO:MyLogger:Logging message 4880
# INFO:MyLogger:Logging message 4881
# INFO:MyLogger:Logging message 4882
# INFO:MyLogger:Logging message 4883
# INFO:MyLogger:Logging message 4884
# INFO:MyLogger:Logging message 4885
# INFO:MyLogger:Logging message 4886
# INFO:MyLogger:Logging message 4887
# INFO:MyLogger:Logging message 4888
# INFO:MyLogger:Logging message 4889
# INFO:MyLogger:Logging message 4890
# INFO:MyLogger:Logging message 4891
# INFO:MyLogger:Logging message 4892
# INFO:MyLogger:Logging message 4893
# INFO:MyLogger:Logging message 4894
# INFO:MyLogger:Logging message 4895
# INFO:MyLogger:Logging message 4896
# INFO:MyLogger:Logging message 4897
# INFO:MyLogger:Logging message 4898
# INFO:MyLogger:Logging message 4899
# INFO:MyLogger:Logging message 4900
# INFO:MyLogger:Logging message 4901
# INFO:MyLogger:Logging message 4902
# INFO:MyLogger:Logging message 4903
# INFO:MyLogger:Logging message 4904
# INFO:MyLogger:Logging message 4905
# INFO:MyLogger:Logging message 4906
# INFO:MyLogger:Logging message 4907
# INFO:MyLogger:Logging message 4908
# INFO:MyLogger:Logging message 4909
# INFO:MyLogger:Logging message 4910
# INFO:MyLogger:Logging message 4911
# INFO:MyLogger:Logging message 4912
# INFO:MyLogger:Logging message 4913
# INFO:MyLogger:Logging message 4914
# INFO:MyLogger:Logging message 4915
# INFO:MyLogger:Logging message 4916
# INFO:MyLogger:Logging message 4917
# INFO:MyLogger:Logging message 4918
# INFO:MyLogger:Logging message 4919
# INFO:MyLogger:Logging message 4920
# INFO:MyLogger:Logging message 4921
# INFO:MyLogger:Logging message 4922
# INFO:MyLogger:Logging message 4923
# INFO:MyLogger:Logging message 4924
# INFO:MyLogger:Logging message 4925
# INFO:MyLogger:Logging message 4926
# INFO:MyLogger:Logging message 4927
# INFO:MyLogger:Logging message 4928
# INFO:MyLogger:Logging message 4929
# INFO:MyLogger:Logging message 4930
# INFO:MyLogger:Logging message 4931
# INFO:MyLogger:Logging message 4932
# INFO:MyLogger:Logging message 4933
# INFO:MyLogger:Logging message 4934
# INFO:MyLogger:Logging message 4935
# INFO:MyLogger:Logging message 4936
# INFO:MyLogger:Logging message 4937
# INFO:MyLogger:Logging message 4938
# INFO:MyLogger:Logging message 4939
# INFO:MyLogger:Logging message 4940
# INFO:MyLogger:Logging message 4941
# INFO:MyLogger:Logging message 4942
# INFO:MyLogger:Logging message 4943
# INFO:MyLogger:Logging message 4944
# INFO:MyLogger:Logging message 4945
# INFO:MyLogger:Logging message 4946
# INFO:MyLogger:Logging message 4947
# INFO:MyLogger:Logging message 4948
# INFO:MyLogger:Logging message 4949
# INFO:MyLogger:Logging message 4950
# INFO:MyLogger:Logging message 4951
# INFO:MyLogger:Logging message 4952
# INFO:MyLogger:Logging message 4953
# INFO:MyLogger:Logging message 4954
# INFO:MyLogger:Logging message 4955
# INFO:MyLogger:Logging message 4956
# INFO:MyLogger:Logging message 4957
# INFO:MyLogger:Logging message 4958
# INFO:MyLogger:Logging message 4959
# INFO:MyLogger:Logging message 4960
# INFO:MyLogger:Logging message 4961
# INFO:MyLogger:Logging message 4962
# INFO:MyLogger:Logging message 4963
# INFO:MyLogger:Logging message 4964
# INFO:MyLogger:Logging message 4965
# INFO:MyLogger:Logging message 4966
# INFO:MyLogger:Logging message 4967
# INFO:MyLogger:Logging message 4968
# INFO:MyLogger:Logging message 4969
# INFO:MyLogger:Logging message 4970
# INFO:MyLogger:Logging message 4971
# INFO:MyLogger:Logging message 4972
# INFO:MyLogger:Logging message 4973
# INFO:MyLogger:Logging message 4974
# INFO:MyLogger:Logging message 4975
# INFO:MyLogger:Logging message 4976
# INFO:MyLogger:Logging message 4977
# INFO:MyLogger:Logging message 4978
# INFO:MyLogger:Logging message 4979
# INFO:MyLogger:Logging message 4980
# INFO:MyLogger:Logging message 4981
# INFO:MyLogger:Logging message 4982
# INFO:MyLogger:Logging message 4983
# INFO:MyLogger:Logging message 4984
# INFO:MyLogger:Logging message 4985
# INFO:MyLogger:Logging message 4986
# INFO:MyLogger:Logging message 4987
# INFO:MyLogger:Logging message 4988
# INFO:MyLogger:Logging message 4989
# INFO:MyLogger:Logging message 4990
# INFO:MyLogger:Logging message 4991
# INFO:MyLogger:Logging message 4992
# INFO:MyLogger:Logging message 4993
# INFO:MyLogger:Logging message 4994
# INFO:MyLogger:Logging message 4995
# INFO:MyLogger:Logging message 4996
# INFO:MyLogger:Logging message 4997
# INFO:MyLogger:Logging message 4998
# INFO:MyLogger:Logging message 4999

# %%
#19 Write a program that handles both IndexError and KeyError using a try-except block.

# Program to handle IndexError and KeyError

my_list = [1, 2, 3]
my_dict = {"a": 10, "b": 20}

try:
    # Trying to access an invalid index
    print("List element:", my_list[5])

    # Trying to access a missing dictionary key
    print("Dictionary value:", my_dict["z"])

except IndexError:
    print("Error: List index out of range.")

except KeyError:
    print("Error: Dictionary key not found.")
# Out:
# Error: List index out of range.

# %%
#20  How would you open a file and read its contents using a context manager in Python?
filename = "example.txt"

with open(filename, "r") as file:
    contents = file.read()

print(contents)

# %%
#21  Write a Python program that reads a file and prints the number of occurrences of a specific word.

# Program to count occurrences of a word in a file

filename = "sample.txt"
word_to_count = "Python"

try:
    with open(filename, "r") as file:
        content = file.read()  # Read entire file content

    # Convert content to lowercase and split into words for case-insensitive counting
    words = content.split()
    count = sum(1 for w in words if w.lower() == word_to_count.lower())

    print(f"The word '{word_to_count}' occurs {count} times in the file.")

except FileNotFoundError:
    print(f"Error: The file '{filename}' does not exist.")
# Out:
# Error: The file 'sample.txt' does not exist.

# %%
#22  How can you check if a file is empty before attempting to read its contents?

import os

filename = "sample.txt"

if os.path.exists(filename) and os.path.getsize(filename) > 0:
    with open(filename, "r") as file:
        content = file.read()
        print(content)
else:
    print(f"The file '{filename}' is empty or does not exist.")
# Out:
# The file 'sample.txt' is empty or does not exist.

# %%
#23  Write a Python program that writes to a log file when an error occurs during file handling.

import logging

# Configure logging to write errors to a file
logging.basicConfig(
    filename="file_errors.log",
    level=logging.ERROR,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

filename = "non_existent_file.txt"

try:
    # Attempt to open and read the file
    with open(filename, "r") as file:
        content = file.read()
        print(content)

except FileNotFoundError as e:
    logging.error("File not found: %s", e)
    print(f"An error occurred. Check 'file_errors.log' for details.")

except IOError as e:
    logging.error("IO error occurred: %s", e)
    print(f"An error occurred. Check 'file_errors.log' for details.")
# Out:
# ERROR:root:File not found: [Errno 2] No such file or directory: 'non_existent_file.txt'
# An error occurred. Check 'file_errors.log' for details.
